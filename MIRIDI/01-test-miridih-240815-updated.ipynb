# %% [markdown]
# # Power Point Slide 생성

# %% [markdown]
# # 환경 설정
#
# #### 참조:  Bedrock 호출
# - 참고: https://docs.anthropic.com/en/api/claude-on-amazon-bedrock

# %%
# pip install boto3

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 시도1: Prompt Chaining
#
# - 목표: 최소한의 API 호출로 Chaining Prompt를 사용하여 20장의 파워포인트 슬라이드를 생성하기
# - 아이디어: 파워포인트 슬라이드 20장을 구성하기 위해 3번의 Bedrock invoke_model API를 호출한다.
#     - (1) Initial prompt를 사용해 전체 아웃라인 짜기 - 즉, 1번째 Bedrock invoke_model API를 호출에서는 토픽에 맞는 전체 개요를 만든다.
#     - (2) Slide prompt를 사용해 1번에서 짠 아웃라인에 맞춰서 디테일한 내용을 불렛 포인트로 정리한 슬라이드를 각각 만든다 - 즉, 2번째 호출에서는 1~10번째 슬라이드의 개요를, 3번째 호출에서는 11~20번째 슬라이드 개요만을 사용해 각 슬라이드에 대한 내용을 자세하게 생성한다.

# %% [markdown]
# ##  1. Outline prompt 준비

# %% [markdown]
# ### 프롬프트 템플릿 파일 기술

# %%
from util.prompt_util import *

# 템플릿 파일의 경로를 지정합니다.
prompt_folder = "prompt_template"
outline_prompt_file_name = "v01_outline_prompt_template.txt"

# %% [markdown]
# ### Outline prompt Template 로딩 및 토픽 추가

# %%
from jinja2 import Template

prompt_file_path = os.path.join(prompt_folder, outline_prompt_file_name)

template_content = load_template_from_file(prompt_file_path)
PROMPT_TEMPLATE = Template(template_content)

TOPIC = "Paris 2024 Olympics Cloasing Ceremony Success Prediction"
outline_prompt = PROMPT_TEMPLATE.render(topic=TOPIC)
# print_json(prompt)
print(outline_prompt)
# Out:
# You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Analyze the given topic thoroughly to write in the provided <output_format> JSON format.
# Return only the JSON object without additional tags or explanations.
#
# <context>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </context>
#
# <instruction>
# 1. Title:
#    - Create a compelling and concise main title that captures the essence of the presentation.
#
# 2. Slides:
#    - Generate 20 slides, including an opening and a closing slide.
#    - For each slide:
#      - Assign a slide_number (01 to 20).
#      - Create a clear and informative slide_title.
#
# 3. Content Guidelines:
#    - Ensure a logical flow and structure throughout the presentation.
#    - Include an introduction slide (slide 02) and a conclusion slide (slide 19).
#
# 4. Common Points:
#    - Include the most important keywords related to the topic.
#    - Ensure each slide contributes to the overall narrative of the presentation.
#    - There should be no duplicate content between slides.
#    - Consider the target audience and tailor the content accordingly.
# </instruction>
#
# <output_format>
# Follow the provided JSON format exactly when writing the results. Strictly adhere to the meaning and format of each field.
# {
#     "title": "[Main presentation title]",
#     "slides": [
#         {
#             "slide_number": "[number] (e.g., 01, 02, ..., 20)",
#             "slide_title": "[Slide title]",
#         }
#     ]
# }
# </output_format>

# %% [markdown]
# ### Outline prompt 실행

# %%
outline, input_tokens, output_tokens = invoke_claude(outline_prompt)
print("\n## Overall Outline by Claude Sonnet3.5:\n")
print(outline)
print(f"\n Input tokens: {input_tokens}, Output tokens: {output_tokens}")
print("\n" + "="*50 + "\n")
# Out:
# {
#     "title": "2024 파리 올림픽 폐회식 성공 예측 분석",
#     "slides": [
#         {
#             "slide_number": "01",
#             "slide_title": "2024 파리 올림픽 폐회식 성공 예측 분석"
#         },
#         {
#             "slide_number": "02",
#             "slide_title": "소개: 파리 올림픽의 의의와 폐회식의 중요성"
#         },
#         {
#             "slide_number": "03",
#             "slide_title": "2024 파리 올림픽 개요 및 주요 특징"
#         },
#         {
#             "slide_number": "04",
#             "slide_title": "역대 올림픽 폐회식 성공 사례 분석"
#         },
#         {
#             "slide_number": "05",
#             "slide_title": "파리 2024 조직위원회의 폐회식 계획"
#         },
#         {
#             "slide_number": "06",
#             "slide_title": "폐회식 장소 및 인프라 준비 현황"
#         },
#         {
#             "slide_number": "07",
#             "slide_title": "예상 참가국 및 선수단 규모"
#         },
#         {
#             "slide_number": "08",
#             "slide_title": "폐회식 예술 공연 및 문화 프로그램"
#         },
#         {
#             "slide_number": "09",
#             "slide_title": "기술 혁신: AR, VR 등 첨단 기술 활용 계획"
#         },
#         {
#             "slide_number": "10",
#             "slide_title": "환경 친화적 폐회식 운영 전략"
#         },
#         {
#             "slide_number": "11",
#             "slide_title": "안전 및 보안 대책"
#         },
#         {
#             "slide_number": "12",
#             "slide_title": "미디어 보도 및 글로벌 중계 전략"
#         },
#         {
#             "slide_number": "13",
#             "slide_title": "관중 참여 및 상호작용 계획"
#         },
#         {
#             "slide_number": "14",
#             "slide_title": "디지털 플랫폼을 통한 폐회식 경험 확장"
#         },
#         {
#             "slide_number": "15",
#             "slide_title": "폐회식 성공을 위한 주요 도전 과제"
#         },
#         {
#             "slide_number": "16",
#             "slide_title": "예상되는 경제적 파급효과"
#         },
#         {
#             "slide_number": "17",
#             "slide_title": "폐회식 성공 지표 및 평가 기준"
#         },
#         {
#             "slide_number": "18",
#             "slide_title": "파리 2024 폐회식 성공 가능성 분석"
#         },
#         {
#             "slide_number": "19",
#             "slide_title": "결론: 폐회식 성공을 위한 핵심 전략"
#         },
#         {
#             "slide_number": "20",
#             "slide_title": "질의응답 및 토론"
#         }
#     ]
# }
#
# ## Overall Outline by Claude Sonnet3.5:
#
# {
#     "title": "2024 파리 올림픽 폐회식 성공 예측 분석",
#     "slides": [
#         {
#             "slide_number": "01",
#             "slide_title": "2024 파리 올림픽 폐회식 성공 예측 분석"
#         },
#         {
#             "slide_number": "02",
#             "slide_title": "소개: 파리 올림픽의 의의와 폐회식의 중요성"
#         },
#         {
#             "slide_number": "03",
#             "slide_title": "2024 파리 올림픽 개요 및 주요 특징"
#         },
#         {
#             "slide_number": "04",
#             "slide_title": "역대 올림픽 폐회식 성공 사례 분석"
#         },
#         {
#             "slide_number": "05",
#             "slide_title": "파리 2024 조직위원회의 폐회식 계획"
#         },
#         {
#             "slide_number": "06",
#             "slide_title": "폐회식 장소 및 인프라 준비 현황"
#         },
#         {
#             "slide_number": "07",
#             "slide_title": "예상 참가국 및 선수단 규모"
#         },
#         {
#             "slide_number": "08",
#             "slide_title": "폐회식 예술 공연 및 문화 프로그램"
#         },
#         {
#             "slide_number": "09",
#             "slide_title": "기술 혁신: AR, VR 등 첨단 기술 활용 계획"
#         },
#         {
#             "slide_number": "10",
#             "slide_title": "환경 친화적 폐회식 운영 전략"
#         },
#         {
#             "slide_number": "11",
#             "slide_title": "안전 및 보안 대책"
#         },
#         {
#             "slide_number": "12",
#             "slide_title": "미디어 보도 및 글로벌 중계 전략"
#         },
#         {
#             "slide_number": "13",
#             "slide_title": "관중 참여 및 상호작용 계획"
#         },
#         {
#             "slide_number": "14",
#             "slide_title": "디지털 플랫폼을 통한 폐회식 경험 확장"
#         },
#         {
#             "slide_number": "15",
#             "slide_title": "폐회식 성공을 위한 주요 도전 과제"
#         },
#         {
#             "slide_number": "16",
#             "slide_title": "예상되는 경제적 파급효과"
#         },
#         {
#             "slide_number": "17",
#             "slide_title": "폐회식 성공 지표 및 평가 기준"
#         },
#         {
#             "slide_number": "18",
#             "slide_title": "파리 2024 폐회식 성공 가능성 분석"
#         },
#         {
#             "slide_number": "19",
#             "slide_title": "결론: 폐회식 성공을 위한 핵심 전략"
#         },
#         {
#             "slide_number": "20",
#             "slide_title": "질의응답 및 토론"
#         }
#     ]
# }
#
#  Input tokens: 409, Output tokens: 925
#
# ==================================================

# %% [markdown]
# ### 슬라이드 타이틀만 보기

# %%
print_slide_titles(outline)
# Out:
# 프레젠테이션 제목: 2024 파리 올림픽 폐회식 성공 예측 분석
#
# 슬라이드 01: 2024 파리 올림픽 폐회식 성공 예측 분석
# 슬라이드 02: 소개: 파리 올림픽의 의의와 폐회식의 중요성
# 슬라이드 03: 2024 파리 올림픽 개요 및 주요 특징
# 슬라이드 04: 역대 올림픽 폐회식 성공 사례 분석
# 슬라이드 05: 파리 2024 조직위원회의 폐회식 계획
# 슬라이드 06: 폐회식 장소 및 인프라 준비 현황
# 슬라이드 07: 예상 참가국 및 선수단 규모
# 슬라이드 08: 폐회식 예술 공연 및 문화 프로그램
# 슬라이드 09: 기술 혁신: AR, VR 등 첨단 기술 활용 계획
# 슬라이드 10: 환경 친화적 폐회식 운영 전략
# 슬라이드 11: 안전 및 보안 대책
# 슬라이드 12: 미디어 보도 및 글로벌 중계 전략
# 슬라이드 13: 관중 참여 및 상호작용 계획
# 슬라이드 14: 디지털 플랫폼을 통한 폐회식 경험 확장
# 슬라이드 15: 폐회식 성공을 위한 주요 도전 과제
# 슬라이드 16: 예상되는 경제적 파급효과
# 슬라이드 17: 폐회식 성공 지표 및 평가 기준
# 슬라이드 18: 파리 2024 폐회식 성공 가능성 분석
# 슬라이드 19: 결론: 폐회식 성공을 위한 핵심 전략
# 슬라이드 20: 질의응답 및 토론

# %% [markdown]
# ## 2. Slide prompt (각 슬라이드에 대한 프롬프트) 생성

# %%
#prompt_file_name = "v01_slide_prompt_template.txt"
prompt_file_name = "v02_slide_prompt_template.txt"

slide_prompt_file_path = os.path.join(prompt_folder, prompt_file_name)

template_content = load_template_from_file(slide_prompt_file_path)
slide_prompt_template = Template(template_content)
slide_prompt_template.render()
# Out:
# 'You are an expert in creating impactful and professional PowerPoint presentations. \nCreate a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.\n\nBased on the following outline for a presentation on topic, \ncreate detailed content for slide_title on slide number.\nInclude bullet points and any relevant information that should be on this slide.\nBut, there should be no duplicated content between slides.\nNow, provide detailed content for the slide.\n\n<topic>\n\n</topic>\n\n<outline>\n\n</outline>\n\n<slide_number>\n\n</slide_number>\n\n<slide_title>\n\n</slide_title>'

# %% [markdown]
# ## 추가 2번의 호출을 통해 슬라이드 생성
# - 1번째 호출에서 1~10번째 슬라이드 생성
# - 2번째 호출에서 11~20번째 슬라이드 생성

# %% [markdown]
# ### 테스트1: 10장을 1~5번째, 6~10번째 슬라이드로 두번에 나눠서 만들면 -> 성공

# %%
from util.prompt_util import create_slide_prompt, create_part_slide_prompt
topic = "Paris 2024 Olympics Cloasing Ceremony Success Prediction"
# include_outline = True
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)

include_outline = False
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)
slide_prompt_list = create_part_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, n_slide = 5, max_slide_num=10)
# Out:
# ## 1th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['01', '02', '03', '04', '05']
# </slide_number>
#
# <slide_title>
# ['2024 파리 올림픽 폐회식 성공 예측 분석', '소개: 파리 올림픽의 의의와 폐회식의 중요성', '2024 파리 올림픽 개요 및 주요 특징', '역대 올림픽 폐회식 성공 사례 분석', '파리 2024 조직위원회의 폐회식 계획']
# </slide_title>
#
#
# ## 2th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['06', '07', '08', '09', '10']
# </slide_number>
#
# <slide_title>
# ['폐회식 장소 및 인프라 준비 현황', '예상 참가국 및 선수단 규모', '폐회식 예술 공연 및 문화 프로그램', '기술 혁신: AR, VR 등 첨단 기술 활용 계획', '환경 친화적 폐회식 운영 전략']
# </slide_title>

# %% [markdown]
# ### 슬라이드 생성

# %% [markdown]
# #### 결과 폴더 생성

# %%
from datetime import datetime
import os

currentDateAndTime = datetime.now()
currentTime = currentDateAndTime.strftime("%Y-%m-%d-%H-%M-%S")
# print("The current time is", currentTime)

output_directory = "./results"
output_directory = os.path.join(output_directory, currentTime)
os.makedirs(output_directory, exist_ok=True)

# %%
from util.prompt_util import generate_slide_content
generate_slide_content(slide_prompt_list, output_directory, include_outline)
# Out:
# 슬라이드 1: 2024 파리 올림픽 폐회식 성공 예측 분석
#
# • 발표 제목: "2024 파리 올림픽 폐회식 성공 예측 분석"
# • 발표자 이름 및 소속
# • 발표 일자
# • 파리 올림픽 로고 이미지
# • 주요 내용 요약:
#   - 파리 올림픽의 의의
#   - 폐회식의 중요성
#   - 성공 요인 분석
#   - 예측 및 제언
#
# 슬라이드 2: 소개: 파리 올림픽의 의의와 폐회식의 중요성
#
# • 파리 올림픽의 의의:
#   - 100년 만의 파리 개최 (1924년 이후)
#   - 지속 가능성과 혁신을 강조한 올림픽
#   - 세계 평화와 화합의 메시지 전달
#
# • 폐회식의 중요성:
#   - 올림픽 정신의 최종 승화
#   - 개최국의 문화와 가치 전달의 기회
#   - 전 세계 관중에게 마지막 인상을 남기는 순간
#   - 다음 올림픽으로의 연결고리 역할
#
# 슬라이드 3: 2024 파리 올림픽 개요 및 주요 특징
#
# • 개최 기간: 2024년 7월 26일 ~ 8월 11일
# • 개최지: 프랑스 파리
# • 참가국 수: 약 206개국 예상
# • 종목 수: 32개 종목, 329개 세부 경기
# • 주요 특징:
#   - 센 강을 활용한 개폐회식 계획
#   - 역사적 건축물을 경기장으로 활용
#   - 친환경 올림픽 추구 (재생 에너지 100% 사용 목표)
#   - 성평등 강조 (남녀 선수 동수 참가)
#
# 슬라이드 4: 역대 올림픽 폐회식 성공 사례 분석
#
# • 2012 런던 올림픽:
#   - 영국 대중문화의 정수를 보여준 공연
#   - 스파이스 걸스, 조지 마이클 등 인기 가수 출연
#
# • 2016 리우 올림픽:
#   - 삼바와 카니발을 결합한 화려한 퍼레이드
#   - 지속 가능성 메시지 전달
#
# • 2020 도쿄 올림픽:
#   - 코로나19 상황에서의 창의적 접근
#   - 첨단 기술을 활용한 가상 공연 도입
#
# • 성공 요인:
#   - 국가 정체성과 문화의 효과적 표현
#   - 대중적 요소와 예술성의 조화
#   - 시대적 메시지 전달
#
# 슬라이드 5: 파리 2024 조직위원회의 폐회식 계획
#
# • 장소: 센 강변 (트로카데로 광장)
# • 주제: "Games Wide Open" (모두에게 열린 올림픽)
# • 주요 계획:
#   - 센 강을 활용한 대규모 수상 퍼레이드
#   - 프랑스 문화유산과 현대 예술의 조화
#   - 디지털 기술을 활용한 관객 참여형 공연
#   - 지속 가능성 강조 (친환경 재료 사용, 에너지 절약)
# • 예상 관중: 현장 60만 명, 전 세계 TV 시청자 수십억 명
# 1th call: Input tokens: 310, Output tokens: 1134
#
# 6번 슬라이드: 폐회식 장소 및 인프라 준비 현황
#
# • 폐회식 장소: 트로카데로 광장 (Trocadéro Square)
#   - 에펠탑을 배경으로 한 상징적인 위치
#   - 수용 인원: 약 100,000명
#
# • 주요 인프라 준비 상황:
#   - 대형 스크린 및 음향 시스템 설치 완료
#   - 임시 관람석 설치 진행 중 (80% 완료)
#   - 안전 및 보안 시설 구축 (90% 완료)
#
# • 교통 인프라:
#   - 지하철 노선 확충 및 임시 셔틀버스 운영 계획 수립
#   - 주변 도로 정비 및 교통 통제 계획 확정
#
# • 기타 시설:
#   - 의료 지원 센터 설치 예정
#   - 다국어 안내 부스 및 편의시설 배치 계획 수립
#
# 7번 슬라이드: 예상 참가국 및 선수단 규모
#
# • 예상 참가국: 206개국
#   - IOC 회원국 전체 참가 예상
#
# • 예상 선수단 규모: 약 11,000명
#   - 하계 올림픽 역대 최대 규모
#
# • 주요 참가국별 예상 선수단 규모:
#   - 미국: 600명
#   - 중국: 550명
#   - 일본: 500명
#   - 프랑스 (개최국): 400명
#
# • 난민 올림픽 선수단: 약 30명 예상
#
# • 성별 분포:
#   - 남성: 52%
#   - 여성: 48% (역대 최고 여성 참가 비율)
#
# • 종목별 참가 선수 수 상위 5개:
#   1. 육상: 2,000명
#   2. 수영: 1,300명
#   3. 축구: 1,000명
#   4. 체조: 800명
#   5. 사이클: 700명
#
# 8번 슬라이드: 폐회식 예술 공연 및 문화 프로그램
#
# • 메인 테마: "화합과 희망의 축제" (Festival of Unity and Hope)
#
# • 주요 공연 구성:
#   1. 프랑스 전통 예술과 현대 문화의 융합 퍼포먼스
#   2. 세계 각국 대표 문화 공연 (5개 대륙 대표)
#   3. 올림픽 하이라이트 영상 쇼
#
# • 특별 초청 아티스트:
#   - 세계적 팝스타 공연 (미정)
#   - 프랑스 유명 클래식 오케스트라 협연
#
# • 문화 프로그램:
#   - 올림픽 기간 중 파리 전역에서 진행된 문화행사 하이라이트 영상
#   - 참가국 대표 문화유산 전시회 결과 발표
#
# • 참여형 프로그램:
#   - 관중과 선수단이 함께하는 대규모 플래시몹
#   - 디지털 기술을 활용한 실시간 글로벌 참여 이벤트
#
# 9번 슬라이드: 기술 혁신: AR, VR 등 첨단 기술 활용 계획
#
# • AR (증강현실) 기술:
#   - 관중석 AR 애플리케이션: 실시간 정보 및 번역 서비스 제공
#   - 공연 중 AR 효과를 통한 시각적 스펙터클 연출
#
# • VR (가상현실) 체험:
#   - 전 세계 시청자를 위한 360도 VR 생중계
#   - 선수촌 및 경기장 가상 투어 제공
#
# • AI 기반 개인화 서비스:
#   - 관람객 맞춤형 정보 및 경로 안내 시스템
#   - 실시간 다국어 자막 및 통역 서비스
#
# • 홀로그램 기술:
#   - 역대 올림픽 명장면 홀로그램 재현
#   - 원격 참가 선수 및 인사 홀로그램 등장
#
# • 드론 쇼:
#   - 1,000대 이상의 드론을 활용한 대규모 항공 디스플레이
#   - 인터랙티브 드론 퍼포먼스 계획
#
# 10번 슬라이드: 환경 친화적 폐회식 운영 전략
#
# • 탄소 중립 목표:
#   - 폐회식 전체 탄소 배출량 0 달성 계획
#   - 탄소 상쇄 프로그램 실시
#
# • 재생 에너지 사용:
#   - 행사장 100% 재생 에너지 전력 공급
#   - 태양광 패널 및 풍력 발전기 임시 설치
#
# • 일회용품 제로화:
#   - 생분해성 소재 사용 의무화
#   - 다회용 컵 및 식기 사용 시스템 도입
#
# • 폐기물 관리:
#   - 분리수거 시스템 강화
#   - 폐기물 재활용 및 업사이클링 프로젝트 실시
#
# • 친환경 교통 수단 장려:
#   - 전기 셔틀버스 운영
#   - 자전거 주차장 확대 및 공유 자전거 서비스 제공
#
# • 그린 캠페인:
#   - 참가자 및 관람객 대상 환경 보호 캠페인 실시
#   - 친환경 행동 인센티브 프로그램 운영
# 2th call: Input tokens: 295, Output tokens: 1762
#
#
# ==================================================
#
# PowerPoint presentation generation complete!
# Total Input Tokens: 605
# Total Output Tokens: 2896
# Processed and saved: ./results/2024-08-20-15-53-47/result_exclude_outline_each_slide.txt

# %% [markdown]
# ### 테스트 2: 12장의 슬라이드를 1~6번째, 7~12번째로 나눠서 만들면 -> 성공

# %%
from util.prompt_util import create_slide_prompt, create_part_slide_prompt
topic = "Paris 2024 Olympics Cloasing Ceremony Success Prediction"
# include_outline = True
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)

include_outline = False
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)
slide_prompt_list = create_part_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, n_slide = 6, max_slide_num=12)
# Out:
# ## 1th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['01', '02', '03', '04', '05', '06']
# </slide_number>
#
# <slide_title>
# ['2024 파리 올림픽 폐회식 성공 예측 분석', '소개: 파리 올림픽의 의의와 폐회식의 중요성', '2024 파리 올림픽 개요 및 주요 특징', '역대 올림픽 폐회식 성공 사례 분석', '파리 2024 조직위원회의 폐회식 계획', '폐회식 장소 및 인프라 준비 현황']
# </slide_title>
#
#
# ## 2th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['07', '08', '09', '10', '11', '12']
# </slide_number>
#
# <slide_title>
# ['예상 참가국 및 선수단 규모', '폐회식 예술 공연 및 문화 프로그램', '기술 혁신: AR, VR 등 첨단 기술 활용 계획', '환경 친화적 폐회식 운영 전략', '안전 및 보안 대책', '미디어 보도 및 글로벌 중계 전략']
# </slide_title>

# %%
from datetime import datetime
import os

currentDateAndTime = datetime.now()
currentTime = currentDateAndTime.strftime("%Y-%m-%d-%H-%M-%S")
# print("The current time is", currentTime)

output_directory = "./results"
output_directory = os.path.join(output_directory, currentTime)
os.makedirs(output_directory, exist_ok=True)

# %%
from util.prompt_util import generate_slide_content
generate_slide_content(slide_prompt_list, output_directory, include_outline)
# Out:
# 각 슬라이드에 대한 상세 내용을 한국어로 제공하겠습니다.
#
# 슬라이드 01: 2024 파리 올림픽 폐회식 성공 예측 분석
# • 발표 제목: "2024 파리 올림픽 폐회식 성공 예측 분석"
# • 발표자 이름 및 소속
# • 발표 일자
# • 주요 내용 미리보기:
#   - 파리 올림픽의 의의
#   - 폐회식의 중요성
#   - 성공 요인 분석
#   - 예측 및 전망
#
# 슬라이드 02: 소개: 파리 올림픽의 의의와 폐회식의 중요성
# • 파리 올림픽의 역사적 의의:
#   - 1900년, 1924년에 이어 세 번째 개최
#   - 100년 만의 파리 올림픽 개최
# • 올림픽 폐회식의 중요성:
#   - 대회의 마지막을 장식하는 행사
#   - 개최국의 문화와 성과를 세계에 알리는 기회
#   - 다음 올림픽 개최국으로의 연결 고리
#
# 슬라이드 03: 2024 파리 올림픽 개요 및 주요 특징
# • 개최 기간: 2024년 7월 26일 - 8월 11일
# • 참가국 수: 예상 206개국
# • 종목 수: 32개 종목, 329개 세부 경기
# • 주요 특징:
#   - 지속 가능성 강조
#   - 성평등 실현 목표
#   - 도시 랜드마크를 활용한 경기장 배치
#
# 슬라이드 04: 역대 올림픽 폐회식 성공 사례 분석
# • 2012 런던 올림픽:
#   - 영국 대중문화의 축제
#   - 세계적 아티스트들의 공연
# • 2016 리우 올림픽:
#   - 삼바와 카니발 문화 강조
#   - 환경 보호 메시지 전달
# • 2020 도쿄 올림픽:
#   - 코로나19 상황에서의 혁신적인 접근
#   - 전통과 현대의 조화
#
# 슬라이드 05: 파리 2024 조직위원회의 폐회식 계획
# • 테마: "파리의 예술과
#  혁신의 조화"
# • 주요 계획:
#   - 세느강을 활용한 수상 퍼레이드
#   - 프랑스 예술과 문화의 집약적 쇼케이스
#   - 친환경 요소 강조
#   - 디지털 기술을 활용한 관객 참여 유도
#
# 슬라이드 06: 폐회식 장소 및 인프라 준비 현황
# • 메인 장소: 트로카데로 광장
#   - 수용 인원: 약 100,000명
#   - 에펠탑을 배경으로 한 장관 연출
# • 보조 장소: 세느강 주변
#   - 강변 산책로를 활용한 관람 공간
# • 교통 인프라:
#   - 지하철 노선 확충
#   - 임시 셔틀버스 운영 계획
# • 안전 대책:
#   - 첨단 보안 시스템 도입
#   - 국제 협력을 통한 테러 대비
# 1th call: Input tokens: 334, Output tokens: 1076
#
# 7번 슬라이드: 예상 참가국 및 선수단 규모
#
# • 예상 참가국 수: 약 206개국
# • 총 선수단 규모: 약 10,500명
# • 주요 참가국:
#   - 미국: 약 600명
#   - 중국: 약 550명
#   - 일본: 약 500명
#   - 프랑스 (개최국): 약 400명
# • 신규 참가국 가능성: 2-3개국
# • 난민 선수단: 약 30-40명 예상
# • 성별 비율: 남성 52%, 여성 48% (예상)
#
# 8번 슬라이드: 폐회식 예술 공연 및 문화 프로그램
#
# • 테마: "파리의 예술과 문화 축제"
# • 주요 공연:
#   - 프랑스 전통 춤과 현대 무용의 조화
#   - 세계적인 프랑스 가수들의 합동 공연
# • 문화 프로그램:
#   - 파리의 상징적 건물을 배경으로 한 프로젝션 매핑
#   - 세계 각국의 전통 의상 퍼레이드
# • 특별 이벤트:
#   - 올림픽 기간 동안의 하이라이트 영상 상영
#   - 차기 올림픽 개최국으로의 성화 인계식
#
# 9번 슬라이드: 기술 혁신: AR, VR 등 첨단 기술 활용 계획
#
# • AR (증강현실) 기술:
#   - 관중석에서 실시간 선수 정보 확인
#   - 가상 올림픽 마스코트와 상호작용
# • VR (가상현실) 체험:
#   - 전 세계 시청자를 위한 360도 폐회식 체험
#   - 가상 올림픽 빌리지 투어
# • AI 기반 개인화 서비스:
#   - 관람객 선호에 따른 맞춤형 정보 제공
# • 드론 쇼:
#   - 500대 이상의 드론을 활용한 공중 디스플레이
#
# 10번 슬라이드: 환경 친화적 폐회식 운영 전략
#
# • 탄소 중립 목표:
#   - 재생 에너지 100% 사용
#   - 탄소 상쇄 프로그램 실행
# • 폐기물 관리:
#   - 일회용품 사용 금지
#   - 분리수거 및 재활용 시스템 구축
# • 친환경 교통:
#   - 전기 셔틀버스 운영
#   - 자전거 주차장 확대
# • 지속 가능한 자재 사용:
#   - 재활용 소재로 만든 무대 및 장식
#   - 생분해성 폐회식 기념품
#
# 11번 슬라이드: 안전 및 보안 대책
#
# • 첨단 보안 시스템:
#   - AI 기반 얼굴 인식 기술 도입
#   - 드론 탐지 및 방어 시스템 구축
# • 테러 대응 계획:
#   - 국제 대테러 협력체계 구축
#   - 특수부대 배치 및 비상 대응 훈련
# • 사이버 보안:
#   - 24시간 모니터링 시스템 운영
#   - 다층적 방화벽 및 암호화 기술 적용
# • 관중 안전:
#   - 비접촉식 보안 검색대 설치
#   - 응급 의료 시설 확충
#
# 12번 슬라이드: 미디어 보도 및 글로벌 중계 전략
#
# • 글로벌 방송권 계약:
#   - 200개국 이상에서 생중계 예정
#   - 스트리밍 플랫폼과의 협력 강화
# • 소셜 미디어 전략:
#   - 실시간 하이라이트 클립 제공
#   - 선수 및 관중 인터뷰 라이브 스트리밍
# • 다국어 지원:
#   - 30개 이상의 언어로 동시 통역 제공
#   - AI 기반 자동 번역 서비스 도입
# • 혁신적 중계 기술:
#   - 8K 초고화질 중계
#   - 다각도 카메라 시스템을 통한 360도 뷰 제공
# 2th call: Input tokens: 310, Output tokens: 1369
#
#
# ==================================================
#
# PowerPoint presentation generation complete!
# Total Input Tokens: 644
# Total Output Tokens: 2445
# Processed and saved: ./results/2024-08-20-15-59-06/result_exclude_outline_each_slide.txt

# %% [markdown]
# ### 테스트 3: 16장의 슬라이드를 1~8번째, 9~16번째로 나눠서 만들면 -> 성공

# %%
from util.prompt_util import create_slide_prompt, create_part_slide_prompt
topic = "Paris 2024 Olympics Cloasing Ceremony Success Prediction"
# include_outline = True
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)

include_outline = False
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)
slide_prompt_list = create_part_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, n_slide = 8, max_slide_num=16)
# Out:
# ## 1th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['01', '02', '03', '04', '05', '06', '07', '08']
# </slide_number>
#
# <slide_title>
# ['2024 파리 올림픽 폐회식 성공 예측 분석', '소개: 파리 올림픽의 의의와 폐회식의 중요성', '2024 파리 올림픽 개요 및 주요 특징', '역대 올림픽 폐회식 성공 사례 분석', '파리 2024 조직위원회의 폐회식 계획', '폐회식 장소 및 인프라 준비 현황', '예상 참가국 및 선수단 규모', '폐회식 예술 공연 및 문화 프로그램']
# </slide_title>
#
#
# ## 2th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['09', '10', '11', '12', '13', '14', '15', '16']
# </slide_number>
#
# <slide_title>
# ['기술 혁신: AR, VR 등 첨단 기술 활용 계획', '환경 친화적 폐회식 운영 전략', '안전 및 보안 대책', '미디어 보도 및 글로벌 중계 전략', '관중 참여 및 상호작용 계획', '디지털 플랫폼을 통한 폐회식 경험 확장', '폐회식 성공을 위한 주요 도전 과제', '예상되는 경제적 파급효과']
# </slide_title>

# %%
from datetime import datetime
import os

currentDateAndTime = datetime.now()
currentTime = currentDateAndTime.strftime("%Y-%m-%d-%H-%M-%S")
# print("The current time is", currentTime)

output_directory = "./results"
output_directory = os.path.join(output_directory, currentTime)
os.makedirs(output_directory, exist_ok=True)

# %%
from util.prompt_util import generate_slide_content
generate_slide_content(slide_prompt_list, output_directory, include_outline)
# Out:
# 주어진 정보를 바탕으로 각 슬라이드의 상세 내용을 한국어로 작성하겠습니다.
#
# 슬라이드 1: 2024 파리 올림픽 폐회식 성공 예측 분석
#
# • 발표 주제 소개
# • 분석의 목적과 중요성
# • 주요 분석 포인트 개요
#   - 역사적 맥락
#   - 현재 준비 상황
#   - 예상되는 도전과 기회
# • 발표 구조 안내
#
# 슬라이드 2: 소개: 파리 올림픽의 의의와 폐회식의 중요성
#
# • 파리 올림픽의 역사적 의미
#   - 1900년, 1924년에 이은 세 번째 개최
# • 올림픽 폐회식의 상징성
#   - 평화와 화합의 메시지 전달
#   - 개최국 문화의 세계적 홍보 기회
# • 폐회식이 올림픽 전체 평가에 미치는 영향
# • 2024 파리 올림픽 폐회식의 특별한 의미
#
# 슬라이드 3: 2024 파리 올림픽 개요 및 주요 특징
#
# • 개최 기간: 2024년 7월 26일 ~ 8월 11일
# • 주요 경기장 소개
# • 새롭게 도입되는 종목
# • 파리 올림픽의 슬로건 및 로고 소개
# • 지속가능성에 중점을 둔 친환경 올림픽 계획
#
# 슬라이드 4: 역대 올림픽 폐회식 성공 사례 분석
#
# • 2012 런던 올림픽 폐회식
#   - 영국 대중문화의 성공적 홍보
# • 2016 리우 올림픽 폐회식
#   - 브라질 전통과 현대의 조화
# • 2020 도쿄 올림픽 폐회식
#   - 팬데믹 상황에서의 혁신적 접근
# • 성공적인 폐회식의 공통 요소 분석
#
# 슬라이드 5: 파리 2024 조직위원회의 폐회식 계획
#
# • 폐회식 기본 컨셉 및 주제
# • 주요 프로그램 구성 요소
# • 혁신적인 기술 활용 계획
#   - AR/VR 기술 통합
#   - 환경 친화적 요소 도입
# • 세계적 아티스트 및 유명 인사 참여 계획
#
# 슬라이드 6: 폐회식 장소 및 인프라 준비 현황
#
# • 폐회식 주 무대: 스타드 드 프랑스
#   - 수용 인원 및 시설 현황
# • 보조 행사장 및 주변 인프라
# • 교통 및 숙박 시설 준비 상황
# • 안전 및 보안 대책
# • 코로나19 대응 계획
#
# 슬라이드 7: 예상 참가국 및 선수단 규모
#
# • 예상 참가국 수: 약 200개국
# • 예상 선수단 규모: 약 10,500명
# • 주요 참가국 및 스타 선수 예상
# • 역대 올림픽 대비 참가 규모 비교
# • 다양성과 포용성 강화 노력
#
# 슬라이드 8: 폐회식 예술 공연 및 문화 프로그램
#
# • 주요 공연 테마 및 구성
# • 프랑스 전통 문화와 현대 예술의 조화
# • 세계적 수준의 공연자 및 아티스트 라인업
# • 관객 참여형 프로그램 계획
# • 디지털 기술을 활용한 혁신적 공연 요소
# 1th call: Input tokens: 379, Output tokens: 1196
#
# 각 슬라이드에 대한 상세 내용을 한국어로 제공하겠습니다:
#
# 9. 기술 혁신: AR, VR 등 첨단 기술 활용 계획
# • AR(증강현실) 기술을 활용한 관중 체험 강화
#   - 스마트폰 앱을 통한 실시간 정보 및 3D 그래픽 제공
# • VR(가상현실) 기술로 전 세계 시청자 몰입도 증대
#   - 360도 카메라를 통한 현장감 있는 중계
# • 드론 쇼를 활용한 화려한 공중 퍼포먼스
# • AI 기술을 적용한 개인화된 폐회식 경험 제공
#
# 10. 환경 친화적 폐회식 운영 전략
# • 재생 에너지 사용 극대화
#   - 태양광, 풍력 등 친환경 에너지원 활용
# • 일회용품 사용 최소화 및 재활용 촉진
# • 탄소 중립 행사 운영을 위한 오프셋 프로그램 도입
# • 대중교통 이용 장려를 통한 탄소 배출 감소
# • 친환경 소재를 활용한 무대 및 장식물 제작
#
# 11. 안전 및 보안 대책
# • 첨단 보안 시스템 구축
#   - AI 기반 얼굴 인식 기술 도입
#   - 드론 탐지 및 방어 시스템 운영
# • 테러 대비 특수 훈련을 받은 보안 인력 배치
# • 관중 밀집 지역 안전 관리 강화
# • 사이버 보안 체계 구축으로 디지털 위협 대응
# • 긴급 상황 대비 신속 대응 매뉴얼 마련
#
# 12. 미디어 보도 및 글로벌 중계 전략
# • 주요 글로벌 방송사와의 중계권 계약 확대
# • 소셜 미디어 플랫폼을 활용한 실시간 정보 공유
# • 다국어 자막 및 통역 서비스 제공으로 접근성 향상
# • 5G 기술을 활용한 초고화질 실시간 스트리밍
# • 국제 미디어 센터 운영으로 취재 편의성 제고
#
# 13. 관중 참여 및 상호작용 계획
# • 관중 참여형 공연 요소 도입
#   - 스마트폰을 활용한 집단 퍼포먼스
# • 실시간 투표 시스템으로 프로그램 일부 결정권 부여
# • 소셜 미디어 해시태그를 활용한 글로벌 참여 유도
# • 관중과 선수 간 실시간 소통 창구 마련
# • 현장 관객을 위한 인터랙티브 체험존 운영
#
# 14. 디지털 플랫폼을 통한 폐회식 경험 확장
# • 전용 모바일 앱 개발
#   - 실시간 정보 제공 및 개인화된 콘텐츠 추천
# • 메타버스 플랫폼에서의 가상 폐회식 동시 진행
# • NFT 기술을 활용한 디지털 기념품 제작 및 판매
# • 폐회식 하이라이트의 온디맨드 스트리밍 서비스
# • AI 챗봇을 통한 24/7 고객 지원 서비스 제공
#
# 15. 폐회식 성공을 위한 주요 도전 과제
# • 코로나19 등 전염병 대응 방안 마련
# • 대규모 행사에 따른 환경 영향 최소화
# • 다양한 문화권을 아우르는 포용적 프로그램 구성
# • 높은 기대치에 부응하는 창의적 콘텐츠 개발
# • 복잡한 기술 시스템의 안정적 운영 보장
#
# 16. 예상되는 경제적 파급효과
# • 관광객 유치를 통한 숙박 및 요식업 수익 증대
# • 중계권 판매 및 광고 수익 예상치
# • 기념품 판매 등 연관 산업 활성화
# • 파리의 국제적 브랜드 가치 상승에 따른 장기적 효과
# • 첨단 기술 산업 발전 촉진 및 관련 일자리 창출
# 2th call: Input tokens: 357, Output tokens: 1419
#
#
# ==================================================
#
# PowerPoint presentation generation complete!
# Total Input Tokens: 736
# Total Output Tokens: 2615
# Processed and saved: ./results/2024-08-20-16-04-26/result_exclude_outline_each_slide.txt

# %% [markdown]
# ### 테스트 4: 18장의 슬라이드를 1~9번째, 10~18번째로 나눠서 만들면 -> 1번째만 만들어지고, 그 다음 10~18번째 슬라이드가 만들어짐
# - 1~9번째 슬라이드를 만드는 rate limit throttling이 걸린 게 아닐까 싶어서 prompt_utils.py에 invoke_claude 함수에 sleep(80) -> sleep(120)을 주어도 현상은 똑같음

# %%
from util.prompt_util import create_slide_prompt, create_part_slide_prompt
topic = "Paris 2024 Olympics Cloasing Ceremony Success Prediction"
# include_outline = True
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)

include_outline = False
# slide_prompt_list = create_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, max_slide_num=20)
slide_prompt_list = create_part_slide_prompt(outline, slide_prompt_template, topic, include_outline=include_outline, n_slide = 9, max_slide_num=18)
# Out:
# ## 1th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['01', '02', '03', '04', '05', '06', '07', '08', '09']
# </slide_number>
#
# <slide_title>
# ['2024 파리 올림픽 폐회식 성공 예측 분석', '소개: 파리 올림픽의 의의와 폐회식의 중요성', '2024 파리 올림픽 개요 및 주요 특징', '역대 올림픽 폐회식 성공 사례 분석', '파리 2024 조직위원회의 폐회식 계획', '폐회식 장소 및 인프라 준비 현황', '예상 참가국 및 선수단 규모', '폐회식 예술 공연 및 문화 프로그램', '기술 혁신: AR, VR 등 첨단 기술 활용 계획']
# </slide_title>
#
#
# ## 2th call's slide_prompt:
#  You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on the following outline for a presentation on topic,
# create detailed content for slide_title on slide number.
# Include bullet points and any relevant information that should be on this slide.
# But, there should be no duplicated content between slides.
# Now, provide detailed content for the slide.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <outline>
# Not Available
# </outline>
#
# <slide_number>
# ['10', '11', '12', '13', '14', '15', '16', '17', '18']
# </slide_number>
#
# <slide_title>
# ['환경 친화적 폐회식 운영 전략', '안전 및 보안 대책', '미디어 보도 및 글로벌 중계 전략', '관중 참여 및 상호작용 계획', '디지털 플랫폼을 통한 폐회식 경험 확장', '폐회식 성공을 위한 주요 도전 과제', '예상되는 경제적 파급효과', '폐회식 성공 지표 및 평가 기준', '파리 2024 폐회식 성공 가능성 분석']
# </slide_title>

# %%
from datetime import datetime
import os

currentDateAndTime = datetime.now()
currentTime = currentDateAndTime.strftime("%Y-%m-%d-%H-%M-%S")
# print("The current time is", currentTime)

output_directory = "./results"
output_directory = os.path.join(output_directory, currentTime)
os.makedirs(output_directory, exist_ok=True)

# %%
from util.prompt_util import generate_slide_content
generate_slide_content(slide_prompt_list, output_directory, include_outline)
# Out:
# bedrock.invoke_model 호출 완료
#
# 호출
# 1th call: Input tokens: 410, Output tokens: 362
#
# bedrock.invoke_model 호출 완료
#
# 호출
# 2th call: Input tokens: 374, Output tokens: 2217
#
#
# ==================================================
#
# PowerPoint presentation generation complete!
# Total Input Tokens: 784
# Total Output Tokens: 2579
# Processed and saved: ./results/2024-08-20-16-30-11/result_exclude_outline_each_slide.txt

# %% [markdown]
# # 시도2: Zero shot prompting 이지만 Role-based prompting, Task-specific instructions, Content structuring, Output constraints를 사용
# : Structure the presentation을 미리 prompt (presentation_prompt) 에 써주고, 각 슬라이드의 아웃풋 토큰 개수에 제한을 두기

# %% [markdown]
# ### 프롬프트 로딩

# %%
all_prompt_file_name = "v01_all_prompt_template.txt"

prompt_file_path = os.path.join(prompt_folder, all_prompt_file_name)

template_content = load_template_from_file(prompt_file_path)
PROMPT_TEMPLATE = Template(template_content)

TOPIC = "Paris 2024 Olympics Cloasing Ceremony Success Prediction"
presentation_prompt = PROMPT_TEMPLATE.render(topic=TOPIC)
# print_json(prompt)
print(presentation_prompt)
# Out:
# You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 20-slide presentation in Korean,
# ensuring a logical flow and comprehensive coverage of the topic.
#
# <topic>
# Paris 2024 Olympics Cloasing Ceremony Success Prediction
# </topic>
#
# <instruction>
# For each slide, provide:
# 1. A clear and concise title
# 2. 3-5 bullet points of key information
# 3. Any relevant data or statistics (if applicable)
#
# Structure the presentation as follows:
# - Slide 1: Introduction
# - Slides 2-3: Background and Context
# - Slides 4-7: Main Points and Analysis
# - Slides 8-9: Predictions and Potential Outcomes
# - Slide 10: Conclusion and Key Takeaways
#
# Present the content for all 20 slides in a clear, organized manner.
# The number of output tokens for each slide must not exceed 100
# </instruction>

# %% [markdown]
# ### 슬라이드 생성

# %%
from util.prompt_util import generate_all_slide_content

generate_all_slide_content(presentation_prompt, output_directory)
# Out:
# Generated Presentation Content:
# Here's a detailed outline for a 20-slide presentation on "Paris 2024 Olympics Closing Ceremony Success Prediction" in Korean:
#
# 1. 제목: 파리 2024 올림픽 폐회식 성공 예측
# • 발표 주제 소개
# • 발표자 소개
# • 주요 논점 요약
#
# 2. 올림픽 폐회식의 중요성
# • 올림픽 정신 구현
# • 개최국 문화 홍보
# • 전 세계 시청자 유치
# • 경제적 영향
#
# 3. 과거 올림픽 폐회식 분석
# • 런던 2012: 8,000만 시청자
# • 리우 2016: 3,500만 시청자
# • 도쿄 2020: 코로나19로 인한 제한적 행사
#
# 4. 파리 2024 올림픽 개요
# • 개최 일정: 2024년 7월 26일 - 8월 11일
# • 주요 경기장: 에펠탑, 베르사유 궁전 등
# • 예상 참가국: 206개국
# • 예상 관람객: 1,300만 명
#
# 5. 파리의 문화적 강점
# • 세계적인 관광 도시
# • 풍부한 예술 및 문화 유산
# • 패션과 요리의 중심지
# • 혁신적인 기술 도시
#
# 6. 폐회식 장소: 세느 강
# • 독특하고 혁신적인 선택
# • 파리의 상징적 장소
# • 16km 구간 활용
# • 예상 현장 관객: 60만 명
#
# 7. 기술 혁신 예측
# • 증강현실(AR) 활용
# • 드론 쇼
# • 실시간 다국어 통역 서비스
# • 5G 기반 실시간 중계
#
# 8. 환경 친화적 접근
# • 재생 에너지 100% 사용 목표
# • 탄소 중립 행사 계획
# • 재활용 소재 활용
# • 대중교통 이용 촉진
#
# 9. 글로벌 참여 전략
# • 소셜 미디어 캠페인
# • 실시간 투표 및 상호작용
# • 가상현실(VR) 체험 제공
# • 다국적 아티스트 참여
#
# 10. 결론 및 주요 시사점
# • 혁신적이고 지속 가능한 폐회식 예상
# • 높은 시청률 및 글로벌 참여 예측
# • 파리의 문화적 강점 극대화 기대
#
# 11. 경제적 영향 예측
# • 예상 관광 수입: 30억 유로
# • 일자리 창출: 약 150,000개
# • TV 중계권 수익: 약 15억 달러
# • 스폰서십 수익: 약 10억 달러
#
# 12. 안전 및 보안 대책
# • 첨단 안면인식 기술 도입
# • 대테러 특수부대 배치
# • 사이버 보안 강화
# • 응급의료 시스템 구축
#
# 13. 코로나19 대응 전략
# • 백신 접종 증명서 확인
# • 실시간 PCR 검사 시행
# • 사회적 거리두기 지침 마련
# • 비대면 서비스 확대
#
# 14. 교통 및 숙박 대책
# • 올림픽 전용 차선 운영
# • 대중교통 24시간 운영
# • 에어비앤비 협력 숙박 제공
# • 스마트 교통 정보 시스템 구축
#
# 15. 문화 프로그램 계획
# • 세계 각국 문화 공연
# • 프랑스 전통 예술 쇼케이스
# • 현대 미술 전시회
# • 국제 음식 축제
#
# 16. 자원봉사자 운영 계획
# • 예상 자원봉사자 수: 50,000명
# • 다국어 서비스 제공
# • 특별 교육 프로그램 운영
# • 자원봉사자 인센티브 제도
#
# 17. 미디어 운영 전략
# • 국제방송센터(IBC) 운영
# • 5G 기반 실시간 중계
# • 소셜 미디어 실시간 업데이트
# • 360도 카메라 중계
#
# 18. 지속 가능성 목표
# • 탄소 배출량 50% 감축
# • 재활용 소재 80% 사용
# • 식품 폐기물 80% 감소
# • 재생 에너지 100% 사용
#
# 19. 레거시 프로그램
# • 스포츠 시설 지역사회 환원
# • 청소년 스포츠 프로그램 확대
# • 환경 보호 캠페인 지속
# • 올림픽 교육 프로그램 운영
#
# 20. 폐회식 성공 예측 요약
# • 혁신적인 장소와 기술 활용
# • 강력한 문화적 콘텐츠
# • 높은 글로벌 참여도
# • 지속 가능성 목표 달성
#
# ==================================================
#
# Total output tokens: 1571
# PowerPoint presentation generation complete!
#
# Individual Slides:
# Processed and saved: ./results/2024-08-18-14-03-01/result_all_slide.txt
