# %% [markdown]
# # Bedrock Claude 및 LangGraph 를 이용한 Prompt Flow - [Advanced] Tool Node 사용

# %%
# !python -V
# Out:
# Python 3.10.14

# %% [markdown]
# # 0. 환경 설정

# %%
# %load_ext autoreload
# %autoreload 2

import sys, os

def add_python_path(module_path):
    if os.path.abspath(module_path) not in sys.path:
        sys.path.append(os.path.abspath(module_path))
        print(f"python path: {os.path.abspath(module_path)} is added")
    else:
        print(f"python path: {os.path.abspath(module_path)} already exists")
    print("sys.path: ", sys.path)

module_path = "../.."
add_python_path(module_path)
# Out:
# python path: /home/sagemaker-user is added
# sys.path:  ['/home/sagemaker-user/miridih-test/langgraph', '/opt/conda/lib/python310.zip', '/opt/conda/lib/python3.10', '/opt/conda/lib/python3.10/lib-dynload', '', '/home/sagemaker-user/.local/lib/python3.10/site-packages', '/opt/conda/lib/python3.10/site-packages', '/home/sagemaker-user']

# %%
# !pip show pydantic
# Out:
# Name: pydantic
# Version: 2.7.0
# Summary: Data validation using Python type hints
# Home-page: https://github.com/pydantic/pydantic
# Author:
# Author-email: Samuel Colvin <s@muelcolvin.com>, Eric Jolibois <em.jolibois@gmail.com>, Hasan Ramezani <hasan.r67@gmail.com>, Adrian Garcia Badaracco <1755071+adriangb@users.noreply.github.com>, Terrence Dorsey <terry@pydantic.dev>, David Montague <david@pydantic.dev>, Serge Matveenko <lig@countzero.co>, Marcelo Trylesinski <marcelotryle@gmail.com>, Sydney Runkle <sydneymarierunkle@gmail.com>, David Hewitt <mail@davidhewitt.io>, Alex Hall <alex.mojaki@gmail.com>
# License:
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: annotated-types, pydantic-core, typing-extensions
# Required-by: amazon_sagemaker_jupyter_scheduler, anthropic, confection, fastapi, gluonts, jupyter_scheduler, langchain, langchain-core, langsmith, sagemaker-core, sagemaker-jupyterlab-extension-common, spacy, thinc, weasel

# %% [markdown]
# ## 1. Bedrock Client 생성

# %%
from pprint import pprint
from termcolor import colored
from utils import bedrock
from utils.bedrock import bedrock_info

boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    endpoint_url=os.environ.get("BEDROCK_ENDPOINT_URL", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
)

print (colored("\n== FM lists ==", "green"))
pprint (bedrock_info.get_list_fm_models(verbose=False))
# Out:
# Create new client
#   Using region: us-east-1
#   Using profile: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
#
# == FM lists ==
# {'Claude-Instant-V1': 'anthropic.claude-instant-v1',
#  'Claude-V1': 'anthropic.claude-v1',
#  'Claude-V2': 'anthropic.claude-v2',
#  'Claude-V2-1': 'anthropic.claude-v2:1',
#  'Claude-V3-5-Sonnet': 'anthropic.claude-3-5-sonnet-20240620-v1:0',
#  'Claude-V3-Haiku': 'anthropic.claude-3-haiku-20240307-v1:0',
#  'Claude-V3-Opus': 'anthropic.claude-3-sonnet-20240229-v1:0',
#  'Claude-V3-Sonnet': 'anthropic.claude-3-sonnet-20240229-v1:0',
#  'Cohere-Embeddings-En': 'cohere.embed-english-v3',
#  'Cohere-Embeddings-Multilingual': 'cohere.embed-multilingual-v3',
#  'Command': 'cohere.command-text-v14',
#  'Command-Light': 'cohere.command-light-text-v14',
#  'Jurassic-2-Mid': 'ai21.j2-mid-v1',
#  'Jurassic-2-Ultra': 'ai21.j2-ultra-v1',
#  'Llama2-13b-Chat': 'meta.llama2-13b-chat-v1',
#  'Titan-Embeddings-G1': 'amazon.titan-embed-text-v1',
#  'Titan-Text-Embeddings-V2': 'amazon.titan-embed-text-v2:0',
#  'Titan-Text-G1': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Express': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Light': 'amazon.titan-text-lite-v1',
#  'Titan-Text-G1-Premier': 'amazon.titan-text-premier-v1:0'}

# %% [markdown]
# ### 모델 ID 및 Bedrock converse API 정의

# %%
from utils.bedrock import *

content_model_id="anthropic.claude-3-haiku-20240307-v1:0"
# content_model_id = "anthropic.claude-3-5-sonnet-20240620-v1:0"
img_model_id = "amazon.titan-image-generator-v1"

# %% [markdown]
# ## 2. Tool 정의
# - Tool: LangChain에서 주로 사용되는 개념으로, 에이전트가 특정 작업을 수행하기 위해 호출할 수 있는 유틸리티 함수. 즉, LangChain에서 LLM이 외부 시스템과 상호작용할 수 있도록 하는 개념
# Langgrpah에서는 Tool Node를 통해 통합될 수 있음
# (ex) 간단한 수학 연산 함수, 외부 DB 쿼리하는 함수

# %%
from typing import Annotated
from langchain_core.tools import tool
from utils.cross_region_inference_prompt_util import *
from jinja2 import Template
from langchain_core.agents import AgentFinish
from langgraph.prebuilt.tool_executor import ToolExecutor


@tool
def create_outline_prompt(
    topic: Annotated[str, "프레젠테이션의 토픽"]
    ):
    """프롬프트의 베이스가 되는 프롬프트 템플릿 파일 불러오기"""
    try:
        # 프롬프트 템플릿 파일의 경로를 지정
        prompt_folder = "prompt_template"
        outline_prompt_file_name = "outline_prompt_template.txt"
        
        outline_prompt_file_path = os.path.join(prompt_folder, outline_prompt_file_name)
        outline_template_content = load_template_from_file(outline_prompt_file_path)
        OUTLINE_PROMPT_TEMPLATE = Template(outline_template_content)
        outline_prompt = OUTLINE_PROMPT_TEMPLATE.render(topic=topic)

        return outline_prompt
    except Exception as e:
        return f"An error occurred: {str(e)}"


@tool
def create_img_prompt(
    topic: Annotated[str, "프레젠테이션의 개요"]
    ):
    """프롬프트의 베이스가 되는 프롬프트 템플릿 파일 불러오기"""
    try:
        # 프롬프트 템플릿 파일의 경로를 지정
        prompt_folder = "prompt_template"
        img_prompt_file_name = "img_prompt_template.txt"
        
        img_prompt_file_path = os.path.join(prompt_folder, img_prompt_file_name)
        img_template_content = load_template_from_file(img_prompt_file_path)
        IMG_PROMPT_TEMPLATE = Template(img_template_content)
        img_prompt = IMG_PROMPT_TEMPLATE.render(topic=topic)

        return img_prompt
    except Exception as e:
        return f"An error occurred: {str(e)}"

# %% [markdown]
# ## 3. Langgrpah 구축

# %% [markdown]
# ### 그래프 정의
# - State 정의
# - 그래프 빌더 정의
# - 노드, 에지 정의
# - 그래프 컴파일

# %% [markdown]
# ### 1. State 정의

# %%
import operator
from typing import TypedDict, Annotated, Any, Sequence, Union
from langgraph.graph import StateGraph, START, END
from langchain_anthropic import ChatAnthropic
from langchain_core.agents import AgentAction, AgentFinish
from langchain_core.messages import BaseMessage

# This defines the object that is passed between each node in the graph. We will create different nodes for each agent and tool
class State(TypedDict):
    topic: Annotated[str, "프레젠테이션 주제"]
    outline_prompt: Annotated[str, "프레젠테이션 개요 생성을 위해 실행할 프롬프트"]
    img_prompt: Annotated[str, "프레젠테이션 주제를 대표하는 이미지 생성을 위해 실행할 프롬프트"]
    outline: Annotated[str, "프레젠테이션 개요"]
    slide_prompt_1: Annotated[str, "슬라이드 내용 생성을 위해 실행할 프롬프트(배치1)"]
    slide_prompt_2: Annotated[str, "슬라이드 내용 생성을 위해 실행할 프롬프트(배치2)"]
    slide_content_1: Annotated[str, "slide_prompt_1로 만들어진 프레젠테이션 내용"]
    slide_content_2: Annotated[str, "slide_prompt_2로 만들어진 프레젠테이션 내용"]
    completed_content: Annotated[str, "최종 생성된 프레젠테이션 내용"]
    img_path: Annotated[str, "생성된 대표 이미지"]

# %% [markdown]
# ### 2. Tool Nodes 정의

# %%
from langgraph.prebuilt import ToolNode, ToolExecutor
from langchain.tools import Tool
from langchain_core.tools import StructuredTool

tools = [
    Tool(
        name="Create Outline Prompt",
        func=create_outline_prompt,
        description="Creates a prompt for outline"
    ),
    Tool(
        name="Create Image Prompt",
        func=create_img_prompt,
        description="Creates a prompt for image"
    )
]

tool_node = ToolNode(tools)
tool_executor = ToolExecutor(tools)
# Out:
# /tmp/ipykernel_12088/3839701094.py:19: LangGraphDeprecationWarning: ToolExecutor is deprecated as of version 0.2.0 and will be removed in 0.3.0. Use langgraph.prebuilt.ToolNode instead.
#   tool_executor = ToolExecutor(tools)

# %% [markdown]
# ### 3. Agent Nodes 정의

# %%
import functools
from langchain_core.messages import AIMessage
from langchain.prompts import PromptTemplate
from langchain.tools import Tool
from langchain_core.agents import AgentFinish
from langgraph.prebuilt.tool_executor import ToolExecutor, ToolInvocation
import json
import boto3
import base64
import random
from textwrap import dedent
from botocore.config import Config
from botocore.exceptions import ClientError
from PIL import Image
import matplotlib.pyplot as plt

# # 템플릿 파일 기술
from utils.cross_region_inference_prompt_util import *
from jinja2 import Template

# 템플릿 파일의 경로를 지정
prompt_folder = "prompt_template"
outline_prompt_file_name = "outline_prompt_template.txt"
prompt_file_path = os.path.join(prompt_folder, outline_prompt_file_name)
template_content = load_template_from_file(prompt_file_path)
PROMPT_TEMPLATE = Template(template_content)

# Tool to create outline prompt
def create_outline_prompt_agent(state:State)-> State:
    topic = state["topic"]
    action = ToolInvocation(
        tool = "Create Outline Prompt",
        tool_input = topic,
    )
    outline_prompt = tool_executor.invoke(action)
    print("\n## Generated Prompt for outline prompt")
    print(outline_prompt)
    return State(outline_prompt=outline_prompt)


# Define the outline generation agent node
def generate_outline(state:State) -> State:
    outline_prompt = state["outline_prompt"]
    response = converse_invoke(boto3_bedrock, content_model_id, outline_prompt)
    
    outline = response['output']['message']['content'][0]['text']
    print("\n## Generated outline")
    print("response: \n", outline)
    return State(outline=outline)


# Create slide content generation prompt (ppt 1-5)
def create_slide_prompt1(state: State) -> State:
    # 슬라이드 내용 생성 prompt template 로딩
    prompt_file_name = "slide_prompt_template.txt"
    slide_prompt_file_path = os.path.join(prompt_folder, prompt_file_name)
    template_content = load_template_from_file(slide_prompt_file_path)
    slide_prompt_template = Template(template_content)
    
    topic = state["topic"]
    outline = state["outline"]

    slide_prompt_1 = slide_prompt_template.render(
        topic = topic,
        outline = outline,
        start_slide = 1,
        end_slide = 5
    )
    print("\n## Generated Prompt for slides 1-5...")
    print(slide_prompt_1)
    return State(slide_prompt_1=slide_prompt_1)


# Create slide content generation prompt (ppt 6-10)
def create_slide_prompt2(state: State) -> State:
    # 슬라이드 내용 생성 prompt template 로딩
    prompt_file_name = "slide_prompt_template.txt"
    slide_prompt_file_path = os.path.join(prompt_folder, prompt_file_name)
    template_content = load_template_from_file(slide_prompt_file_path)
    slide_prompt_template = Template(template_content)
    
    topic = state["topic"]
    outline = state["outline"]

    slide_prompt_2 = slide_prompt_template.render(
        topic = topic,
        outline = outline,
        start_slide = 6,
        end_slide = 10
    )
    print("\n## Generated Prompt for slides 6-10...")
    print(slide_prompt_2)
    return State(slide_prompt_2=slide_prompt_2)


# Generate slide content (ppt 1-5)
def generate_slides_phase1(state:State) -> State:
    slide_prompt_1 = state["slide_prompt_1"]
    
    response1 = converse_invoke(boto3_bedrock, content_model_id, slide_prompt_1)
    # response1 = converse_invoke_with_backoff(boto3_bedrock, content_model_id, slide_prompt1)
    
    output_message1 = response1['output']['message']['content'][0]['text']
    print("\n## Generated content for slides 1-5...") 
    print(output_message1)
    return State(slide_content_1=output_message1)


# Generate slide content (ppt 6-10)
def generate_slides_phase2(state:State) -> State:
    slide_prompt_2 = state["slide_prompt_2"]
 
    response2 = converse_invoke(boto3_bedrock, content_model_id, slide_prompt_2)
    # response2 = converse_invoke_with_backoff(boto3_bedrock, content_model_id, slide_prompt2)

    output_message2 = response2['output']['message']['content'][0]['text']
    print("\n## Generated content for slides 6-10...") 
    print(output_message2)
    return State(slide_content_2=output_message2)


# Tool to create image prompt
def create_image_prompt_agent(state:State)-> State:
    topic = state["topic"]
    
    action = ToolInvocation(
        tool = "Create Image Prompt",
        tool_input = topic,
    )
    
    img_prompt = tool_executor.invoke(action)
    print("\n## Generated Prompt for image prompt")
    print(img_prompt)
    return State(img_prompt=img_prompt)


# Define the image generation agent node
def image_generator(state: State) -> State:
    img_prompt = state["img_prompt"]
    # Generate a random seed.
    seed = random.randint(0, 2147483647)

    # Prepare the request
    native_request = {
        "taskType": "TEXT_IMAGE",
        "textToImageParams": {"text": img_prompt},
        "imageGenerationConfig": {
            "numberOfImages": 1,
            "quality": "standard",
            "cfgScale": 8.0,
            "height": 512,
            "width": 512,
            "seed": seed,
        },
    }

    try:
        # Invoke the model with the request.
        response = boto3_bedrock.invoke_model(modelId=img_model_id, body=json.dumps(native_request))

        # Decode the response body.
        model_response = json.loads(response["body"].read())

        # Extract the image data.
        base64_image_data = model_response["images"][0]

        # Save the generated image to a local folder.
        i, output_dir = 1, "img_output"
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        while os.path.exists(os.path.join(output_dir, f"titan_{i}.png")):
            i += 1

        image_data = base64.b64decode(base64_image_data)

        image_path = os.path.join(output_dir, f"titan_{i}.png")
        with open(image_path, "wb") as file:
            file.write(image_data)

        print(f"The generated image has been saved to {image_path}")

    except ClientError as e:
        print(f"An error occurred: {e}")
        image_path = None

    return State(img_path=image_path)


def completed_slides(state:State) -> State:
    slide_content_1=state["slide_content_1"]
    slide_content_2=state["slide_content_2"]
    img_path=state["img_path"]

    completed_content = slide_content_1 + slide_content_2

    # Open an image file
    # img = Image.open(img_path)

    print("\n## Completed Powerpoint slides...")
    # print("\n### Image...")
    # plt.imshow(img)
    # plt.axis('off')  # Hide axis
    # plt.show()
    print("\n### Slide contents...")
    print(completed_content)
    print("\n### Image...")
    print(img_path)
    
    return State(completed_content=completed_content)

# %% [markdown]
# ### 4. 그래프 생성 및 정의 (노드 추가, 엣지 정의), 그래프 컴파일

# %%
graph_builder = StateGraph(State)

graph_builder.add_node("create_outline_prompt_agent", create_outline_prompt_agent)
graph_builder.add_node("generate_outline", generate_outline)
graph_builder.add_node("create_slide_prompt1",create_slide_prompt1)
graph_builder.add_node("create_slide_prompt2",create_slide_prompt2)
graph_builder.add_node("generate_slides_phase1", generate_slides_phase1)
graph_builder.add_node("generate_slides_phase2", generate_slides_phase2)
graph_builder.add_node("create_image_prompt_agent", create_image_prompt_agent)
graph_builder.add_node("image_generator", image_generator)
graph_builder.add_node("completed_slides", completed_slides)

graph_builder.add_edge(START,"create_outline_prompt_agent")
graph_builder.add_edge("create_outline_prompt_agent","generate_outline")
graph_builder.add_edge("generate_outline","create_image_prompt_agent")
graph_builder.add_edge("generate_outline","create_slide_prompt1")
graph_builder.add_edge("generate_outline","create_slide_prompt2")
graph_builder.add_edge("create_slide_prompt1","generate_slides_phase1")
graph_builder.add_edge("create_slide_prompt2","generate_slides_phase2")
graph_builder.add_edge("generate_slides_phase1","completed_slides")
graph_builder.add_edge("generate_slides_phase2","completed_slides")
graph_builder.add_edge("create_image_prompt_agent","image_generator")
graph_builder.add_edge("image_generator","completed_slides")

graph_builder.add_edge("completed_slides", END)

# 그래프 컴파일
graph = graph_builder.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %% [markdown]
# ## 4. Langgraph 실행

# %% [markdown]
# ### 그래프를 실행할 함수 정의

# %%
def run_prompt(topic: str):
    result = graph.invoke(State(topic=topic))
    return result["completed_content"]

# %%
TOPIC = "Activities to do on New Year's day"

# %% [markdown]
# ### 그래프 실행

# %%
run_prompt(TOPIC)
# Out:
# /tmp/ipykernel_12088/2403767607.py:31: LangGraphDeprecationWarning: ToolInvocation is deprecated as of version 0.2.0 and will be removed in 0.3.0. Use langgraph.prebuilt.ToolNode instead.
#   action = ToolInvocation(
# ## Generated Prompt for outline prompt
# You are an expert in creating impactful and professional PowerPoint presentations.
# Create a detailed outline for a 10-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Analyze the given topic thoroughly to write in the provided <output_format> JSON format.
# Return only the JSON object without additional tags or explanations.
#
# <context>
# Activities to do on New Year's day
# </context>
#
# <instruction>
# 1. Title:
#    - Create a compelling and concise main title that captures the essence of the presentation.
#
# 2. Slides:
#    - Generate 10 slides, including an opening and a closing slide.
#    - For each slide:
#      - Assign a slide_number (01 to 10).
#      - Create a clear and informative slide_title.
#
# 3. Content Guidelines:
#    - Ensure a logical flow and structure throughout the presentation.
#    - Include an introduction slide (slide 02) and a conclusion slide (slide 09).
#
# 4. Common Points:
#    - Include the most important keywords related to the topic.
#    - Ensure each slide contributes to the overall narrative of the presentation.
#    - There should be no duplicate content between slides.
#    - Consider the target audience and tailor the content accordingly.
# </instruction>
#
# <output_format>
# Follow the provided JSON format exactly when writing the results. Strictly adhere to the meaning and format of each field.
# {
#     "title": "[Main presentation title]",
#     "slides": [
#         {
#             "slide_number": "[number] (e.g., 01, 02, ...,10)",
#             "slide_title": "[Slide title]",
#         }
#     ]
# }
# </output_format>
#
# ## Generated outline
# response:
#  {
#     "title": "새해 첫 날 즐기기",
#     "slides": [
#         {
#             "slide_number": "01",
#             "slide_title": "새해 축제"
#         },
#         {
#             "slide_number": "02",
#             "slide_title": "새해맞이의 의미"
#         },
#         {
#             "slide_number": "03",
#             "slide_title": "새해 음식"
#         },
#         {
#             "slide_number": "04",
#             "slide_title": "새해 풍습"
#         },
#         {
#             "slide_number": "05",
#             "slide_title": "새해 운세 점치기"
#         },
#         {
#             "slide_number": "06",
#             "slide_title": "새해 선물"
#         },
#         {
#             "slide_number": "07",
#             "slide_title": "새해 가족 모이기"
#         },
#         {
#             "slide_number": "08",
#             "slide_title": "새해 활동"
#         },
#         {
#             "slide_number": "09",
#             "slide_title": "새해 다짐"
#         },
#         {
#             "slide_number": "10",
#             "slide_title": "새해 축하!"
#         }
#     ]
# }
#
# ## Generated Prompt for slides 1-5...
# You are an expert in creating impactful and professional PowerPoint presentations.
# Your task is to create detailed content for a specific slide in 10-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on this {
#     "title": "새해 첫 날 즐기기",
#     "slides": [
#         {
#             "slide_number": "01",
#             "slide_title": "새해 축제"
#         },
#         {
#             "slide_number": "02",
#             "slide_title": "새해맞이의 의미"
#         },
#         {
#             "slide_number": "03",
#             "slide_title": "새해 음식"
#         },
#         {
#             "slide_number": "04",
#             "slide_title": "새해 풍습"
#         },
#         {
#             "slide_number": "05",
#             "slide_title": "새해 운세 점치기"
#         },
#         {
#             "slide_number": "06",
#             "slide_title": "새해 선물"
#         },
#         {
#             "slide_number": "07",
#             "slide_title": "새해 가족 모이기"
#         },
#         {
#             "slide_number": "08",
#             "slide_title": "새해 활동"
#         },
#         {
#             "slide_number": "09",
#             "slide_title": "새해 다짐"
#         },
#         {
#             "slide_number": "10",
#             "slide_title": "새해 축하!"
#         }
#     ]
# } of the Activities to do on New Year's day, Generate detailed content for slides 1 to 5.
# For each slide, include:
# 1. Slide title
# 2. Main content points (3-5 bullet points)
# 3. Relevant data or examples
# 4. Suggesion for visuals (e.g., image, chart, graph)
# 5. A brief speaker note (1-2 sentences)
#
# ## Generated Prompt for slides 6-10...
# You are an expert in creating impactful and professional PowerPoint presentations.
# Your task is to create detailed content for a specific slide in 10-slide presentation in Korean, ensuring a logical flow and comprehensive coverage of the topic.
#
# Based on this {
#     "title": "새해 첫 날 즐기기",
#     "slides": [
#         {
#             "slide_number": "01",
#             "slide_title": "새해 축제"
#         },
#         {
#             "slide_number": "02",
#             "slide_title": "새해맞이의 의미"
#         },
#         {
#             "slide_number": "03",
#             "slide_title": "새해 음식"
#         },
#         {
#             "slide_number": "04",
#             "slide_title": "새해 풍습"
#         },
#         {
#             "slide_number": "05",
#             "slide_title": "새해 운세 점치기"
#         },
#         {
#             "slide_number": "06",
#             "slide_title": "새해 선물"
#         },
#         {
#             "slide_number": "07",
#             "slide_title": "새해 가족 모이기"
#         },
#         {
#             "slide_number": "08",
#             "slide_title": "새해 활동"
#         },
#         {
#             "slide_number": "09",
#             "slide_title": "새해 다짐"
#         },
#         {
#             "slide_number": "10",
#             "slide_title": "새해 축하!"
#         }
#     ]
# } of the Activities to do on New Year's day, Generate detailed content for slides 6 to 10.
# For each slide, include:
# 1. Slide title
# 2. Main content points (3-5 bullet points)
# 3. Relevant data or examples
# 4. Suggesion for visuals (e.g., image, chart, graph)
# 5. A brief speaker note (1-2 sentences)
#
# ## Generated Prompt for image prompt
# You are a web designer.
# Your task is to create a representative image for a presentation that matches the given Activities to do on New Year's day of the presenstation slides.
# /tmp/ipykernel_12088/2403767607.py:126: LangGraphDeprecationWarning: ToolInvocation is deprecated as of version 0.2.0 and will be removed in 0.3.0. Use langgraph.prebuilt.ToolNode instead.
#   action = ToolInvocation(
# The generated image has been saved to img_output/titan_4.png
#
# ## Generated content for slides 6-10...
# 제 6 슬라이드: 새해 선물
#
# 1. 슬라이드 제목: 새해 선물
#
# 2. 주요 내용 포인트:
#    - 새해에는 가족과 친구들에게 선물을 주고받는 것이 전통적인 풍습
#    - 선물은 사랑과 존중의 표현
#    - 실용적이고 의미 있는 선물이 좋음
#    - 전통적인 선물로는 과일, 과자, 홍삼, 전통 공예품 등이 있음
#    - 올해는 에코 친화적이고 지속 가능한 선물을 선택하는 것도 좋음
#
# 3. 관련 데이터 및 예시:
#    - 2022년 새해 선물 트렌드: 친환경 제품, 개인화된 선물, 홈케어 용품
#    - 새해 선물 비용 평균: 약 30,000원
#
# 4. 시각자료 제안:
#    - 새해 선물 아이디어 이미지
#    - 다양한 새해 선물 제품 이미지
#    - 선물 포장 방법 예시
#
# 5. 발표자 노트:
#    새해를 맞이하여 가족과 친구들에게 사랑과 감사의 마음을 전할 수 있는 선물을 선택하는 것이 중요합니다. 친환경적이고 개인적인 선물이 좋은 선택이 될 수 있습니다.
#
# 제 7 슬라이드: 새해 가족 모이기
#
# 1. 슬라이드 제목: 새해 가족 모이기
#
# 2. 주요 내용 포인트:
#    - 새해에는 가족들이 모여 함께 시간을 보내는 것이 중요한 전통
#    - 가족들이 모여 새해 인사를 나누고 함께 식사를 하는 것이 대표적
#    - 가족 간 이야기를 나누며 화합과 유대감을 강화
#    - 가족 사진 촬영, 가족 게임, 전통 놀이 등 다양한 활동을 함께 할 수 있음
#    - 가족 간 새해 계획과 목표를 공유하는 것도 좋음
#
# 3. 관련 데이터 및 예시:
#    - 새해 가족 모임 참여율: 약 85%
#    - 가족들이 즐겨하는 새해 활동: 가족 사진 촬영(60%), 전통 놀이(45%), 가족 게임(40%)
#
# 4. 시각자료 제안:
#    - 가족이 함께 모인 모습의 이미지
#    - 새해 가족 모임 현장 사진
#    - 가족들이 함께 하는 전통 놀이 이미지
#
# 5. 발표자 노트:
#    새해에는 가족들이 모여 함께 시간을 보내며 화합과 유대감을 느끼는 것이 중요합니다. 가족들이 모여 새해 인사를 나누고, 가족 게임이나 전통 놀이를 함께 즐기면서 소중한 추억을 만들 수 있습니다.
#
# 제 8 슬라이드: 새해 활동
#
# 1. 슬라이드 제목: 새해 활동
#
# 2. 주요 내용 포인트:
#    - 새해에는 전통적인 활동들이 많이 이루어짐
#    - 첫 일출 보기, 소원 빌기, 차례 지내기 등이 대표적
#    - 해마다 방문객이 늘어나는 명소들이 많음
#    - 새해에는 국내외 여행을 떠나는 사람들도 많음
#    - 새해에는 스포츠 경기나 공연 관람 등 다양한 여가 활동도 가능
#
# 3. 관련 데이터 및 예시:
#    - 첫 일출 보는 명소 방문객 수: 약 100만 명
#    - 새해 여행객 증가율: 전년 대비 약 20% 증가
#    - 새해 스포츠 경기 관람객 수: 약 50만 명
#
# 4. 시각자료 제안:
#    - 첫 일출 장면 이미지
#    - 새해 명소 모습 사진
#    - 새해 여행지 풍경 이미지
#    - 새해 스포츠 경기 현장 사진
#
# 5. 발표자 노트:
#    새해에는 전통적인 활동들이 많이 이루어지며, 국내외 여행과 스포츠 경기 관람 등 다양한 여가 활동도 가능합니다. 첫 일출 보기, 소원 빌기, 차례 지내기 등의 활동은 새해를 맞이하는 의미있는 경험이 될 수 있습니다.
#
# 제 9 슬라이드: 새해 다짐
#
# 1. 슬라이드 제목: 새해 다짐
#
# 2. 주요 내용 포인트:
#    - 새해를 맞아 새로운 시작, 변화, 목표를 설정하는 것이 중요
#    - 건강, 재정, 관계, 자기계발 등 다양한 분야에서 새해 다짐을 할 수 있음
#    - 구체적이고 실천 가능한 다짐이 중요
#    - 새해 다짐을 지키기 위해 실천 계획을 세우는 것이 효과적
#    - 가족이나 친구들과 새해 다짐을 공유하면 서로 격려할 수 있음
#
# 3. 관련 데이터 및 예시:
#    - 새해 다짐 상위 카테고리: 건강(45%), 재정(35%), 자기계발(25%)
#    - 새해 다짐 성공률: 약 25%
#    - 새해 다짐 사례: 금연, 운동 습관 만들기, 저축 목표 세우기, 취미 활동 시작하기
#
# 4. 시각자료 제안:
#    - 새해 다짐 아이콘 또는 일러스트레이션
#    - 새해 다짐을 적은 메모지 이미지
#    - 새해 다짐 달성을 격려하는 메시지 포스터
#
# 5. 발표자 노트:
#    새해는 새로운 시작과 변화를 위한 기회입니다. 건강, 재정, 관계 등 다양한 분야에서 구체적이고 실천 가능한 새해 다짐을 세우고, 이를 지키기 위한 계획을 수립하는 것이 중요합니다. 가족과 친구들과 다짐을 공유하며 서로 격려하는 것도 도움이 될 수 있습니다.
#
# 제 10 슬라이드: 새해 축하!
#
# 1. 슬라이드 제목: 새해 축하!
#
# 2. 주요 내용 포인트:
#    - 새해를 맞이하여 모두에게 행복과 건강이 가득하기를 기원
#    - 새로운 한 해가 풍요롭고 발전적인 시간이 되기를 바람
#    - 새해에는 더욱 가족과 친구들과의 유대를 돈독히 하고자 함
#    - 새로운 시작과 변화의 기회를 맞이하게 되어 기쁨
#    - 모두가 함께 새로운 희망과 꿈을 펼칠 수 있기를 기대
#
# 3. 관련 데이터 및 예시:
#    - 새해 인사말 예시: "새해 복 많이 받으세요!", "새해 복 가득하세요!", "새해 복 많이 받아 행복한 한 해 되세요!"
#
# 4. 시각자료 제안:
#    - 새해 축하 메시지 이미지 또는 아이콘
#    - 새해 축제 분위기의 이미지
#    - 가족과 친구들이 함께 새해를 축하하는 모습의 사진
#
# 5. 발표자 노트:
#    새해를 맞이하여 모두에게 행복과 건강이 가득하길 바랍니다. 새로운 시작과 변화의 기회를 맞이하게 되어 기쁨이 크며, 가족과 친구들과 함께 새로운 희망과 꿈을 펼칠 수 있기를 기대합니다. 새해 복 많이 받으세요!
#
# ## Generated content for slides 1-5...
# 슬라이드 1: 새해 축제
#
# 1. 슬라이드 제목: 새해 축제
#
# 2. 주요 내용 포인트:
# - 한국의 대표적인 새해 축제: 설날 (Lunar New Year)
# - 설날 기간 동안 가족과 친구들이 모여 전통 음식을 나누며 즐기는 명절
# - 세배 예절, 전통놀이, 돼지고기 요리 등 다양한 행사와 풍습 있음
# - 설날 연휴 동안 전국 각지에서 축제와 불꽃놀이가 열려 새해를 맞이함
#
# 3. 관련 데이터 또는 예시:
# - 설날 연휴 기간 동안 한국 전역에서 진행되는 600여 개의 축제 행사
# - 설날 연휴 기간 동안 가족과 친구들이 모여 평균 3.5일 동안 휴식을 취함
#
# 4. 제안 시각 자료:
# - 설날 장면을 보여주는 사진 또는 동영상
# - 한국의 전통 놀이와 음식을 소개하는 이미지
#
# 5. 발표자 메모:
# 설날은 한국의 대표적인 명절로, 가족과 친구들이 모여 세배 예절을 행하고 전통 음식을 나누며 새해를 축하합니다. 이번 슬라이드에서는 설날 축제의 주요 특징과 활동을 소개하겠습니다.
#
# 슬라이드 2: 새해맞이의 의미
#
# 1. 슬라이드 제목: 새해맞이의 의미
#
# 2. 주요 내용 포인트:
# - 새해맞이는 과거를 돌아보고 새로운 시작을 다짐하는 중요한 시기
# - 가족과 친구들이 모여 새로운 시작을 축하하며 서로를 격려하고 응원함
# - 새해에는 모든 사람들이 건강과 행복, 성공을 기원하며 희망을 품음
# - 새해맞이는 과거의 아쉬움을 지우고 더 나은 미래를 향한 계기가 됨
#
# 3. 관련 데이터 또는 예시:
# - 새해맞이 시 '새해 복 많이 받으세요' 등의 인사말을 교환하며 서로를 축복함
# - 새해 아침 해맞이 행사에 많은 사람들이 모여 새로운 한 해의 시작을 기념함
#
# 4. 제안 시각 자료:
# - 가족 및 친구들이 새해를 축하하는 모습의 사진
# - 새해 소망이나 다짐을 나타내는 이미지
#
# 5. 발표자 메모:
# 새해맞이는 과거를 돌아보고 새로운 시작을 다짐하는 중요한 시기입니다. 가족과 친구들이 모여 서로를 격려하고 새해의 행복과 성공을 기원하며, 이는 과거의 아쉬움을 지우고 더 나은 미래를 향한 계기가 됩니다.
#
# 슬라이드 3: 새해 음식
#
# 1. 슬라이드 제목: 새해 음식
#
# 2. 주요 내용 포인트:
# - 한국의 대표적인 새해 음식: 떡국, 나물, 돼지고기 요리 등
# - 떡국은 새해를 맞이하는 대표 음식으로, 새해 첫날 먹으면 한 살 더 먹는다고 믿음
# - 나물은 새해의 건강과 다복을 기원하는 의미가 있음
# - 돼지고기는 풍요와 행복을 상징하는 음식으로, 새해 첫날 먹는다고 함
#
# 3. 관련 데이터 또는 예시:
# - 설날 연휴 기간 동안 가족들이 함께 모여 떡국, 나물, 돼지고기 요리를 즐김
# - 새해 첫날 아침에 먹는 떡국이 가장 대표적인 새해 음식
#
# 4. 제안 시각 자료:
# - 다양한 새해 음식의 이미지 또는 음식을 준비하는 모습의 사진
# - 새해 음식을 소개하는 인포그래픽
#
# 5. 발표자 메모:
# 새해를 맞이하는 한국의 대표적인 음식들에 대해 소개하겠습니다. 떡국, 나물, 돼지고기 요리 등은 새해의 건강, 행복, 풍요를 기원하는 의미가 담겨 있습니다. 이러한 전통 음식들은 가족과 친구들이 함께 나누며 새해를 축하하는 중요한 역할을 합니다.
#
# 슬라이드 4: 새해 풍습
#
# 1. 슬라이드 제목: 새해 풍습
#
# 2. 주요 내용 포인트:
# - 세배: 윗사람에게 새해 인사를 드리는 전통 풍습
# - 윷놀이: 흰 색 윷을 던져 점을 치는 전통 놀이
# - 제기차기: 종이로 만든 제기를 차며 노는 전통 놀이
# - 망월수: 새해 첫날 아침 일찍 일어나 달을 보며 소원을 빎
#
# 3. 관련 데이터 또는 예시:
# - 연령과 성별에 따른 세배 예법이 존재함
# - 설날 연휴 기간 동안 가족들이 함께 윷놀이와 제기차기를 즐김
# - 새해 첫날 아침 일찍 일어나 달을 보며 소원을 빌는 사람들이 많음
#
# 4. 제안 시각 자료:
# - 세배, 윷놀이, 제기차기 등의 전통 풍습을 보여주는 사진 또는 영상
# - 새해 첫날 아침 달을 바라보는 사람들의 모습을 담은 이미지
#
# 5. 발표자 메모:
# 이번 슬라이드에서는 새해 풍습에 대해 살펴보겠습니다. 세배, 윷놀이, 제기차기 등의 전통 놀이와 망월수 등의 의미 있는 풍습들은 한국 고유의 새해 문화를 보여줍니다. 이러한 풍습들은 가족과 친구들이 함께 즐기며 새해를 맞이하는 중요한 의미를 지니고 있습니다.
#
# 슬라이드 5: 새해 운세 점치기
#
# 1. 슬라이드 제목: 새해 운세 점치기
#
# 2. 주요 내용 포인트:
# - 새해 첫날 점을 치며 한 해의 운세를 살펴보는 전통 풍습
# - 토정비결: 토정 이지함이라는 학자가 창안한 운세 점치기 방식
# - 사주풀이: 태어난 년, 월, 일, 시를 바탕으로 한 운세 점치기
# - 신년운세: 전문 점술가들이 새해 운세를 점쳐 알려줌
#
# 3. 관련 데이터 또는 예시:
# - 설날 연휴 기간 동안 전국 각지에서 운세 점치기 행사가 열림
# - 많은 사람들이 새해 첫날 가족들과 함께 운세를 점쳐보는 전통이 있음
#
# 4. 제안 시각 자료:
# - 토정비결과 사주풀이를 보여주는 이미지 또는 인포그래픽
# - 새해 운세를 점치는 사람들의 모습을 담은 사진
#
# 5. 발표자 메모:
# 새해 첫날 운세를 점치는 것은 오랜 한국의 전통 풍습입니다. 토정비결, 사주풀이 등의 방식으로 한 해의 운세를 살펴보며, 전문 점술가들이 새해 운세를 알려주기도 합니다. 이를 통해 새해에 대한 기대와 희망을 품을 수 있습니다.
#
# ## Completed Powerpoint slides...
#
# ### Slide contents...
# 슬라이드 1: 새해 축제
#
# 1. 슬라이드 제목: 새해 축제
#
# 2. 주요 내용 포인트:
# - 한국의 대표적인 새해 축제: 설날 (Lunar New Year)
# - 설날 기간 동안 가족과 친구들이 모여 전통 음식을 나누며 즐기는 명절
# - 세배 예절, 전통놀이, 돼지고기 요리 등 다양한 행사와 풍습 있음
# - 설날 연휴 동안 전국 각지에서 축제와 불꽃놀이가 열려 새해를 맞이함
#
# 3. 관련 데이터 또는 예시:
# - 설날 연휴 기간 동안 한국 전역에서 진행되는 600여 개의 축제 행사
# - 설날 연휴 기간 동안 가족과 친구들이 모여 평균 3.5일 동안 휴식을 취함
#
# 4. 제안 시각 자료:
# - 설날 장면을 보여주는 사진 또는 동영상
# - 한국의 전통 놀이와 음식을 소개하는 이미지
#
# 5. 발표자 메모:
# 설날은 한국의 대표적인 명절로, 가족과 친구들이 모여 세배 예절을 행하고 전통 음식을 나누며 새해를 축하합니다. 이번 슬라이드에서는 설날 축제의 주요 특징과 활동을 소개하겠습니다.
#
# 슬라이드 2: 새해맞이의 의미
#
# 1. 슬라이드 제목: 새해맞이의 의미
#
# 2. 주요 내용 포인트:
# - 새해맞이는 과거를 돌아보고 새로운 시작을 다짐하는 중요한 시기
# - 가족과 친구들이 모여 새로운 시작을 축하하며 서로를 격려하고 응원함
# - 새해에는 모든 사람들이 건강과 행복, 성공을 기원하며 희망을 품음
# - 새해맞이는 과거의 아쉬움을 지우고 더 나은 미래를 향한 계기가 됨
#
# 3. 관련 데이터 또는 예시:
# - 새해맞이 시 '새해 복 많이 받으세요' 등의 인사말을 교환하며 서로를 축복함
# - 새해 아침 해맞이 행사에 많은 사람들이 모여 새로운 한 해의 시작을 기념함
#
# 4. 제안 시각 자료:
# - 가족 및 친구들이 새해를 축하하는 모습의 사진
# - 새해 소망이나 다짐을 나타내는 이미지
#
# 5. 발표자 메모:
# 새해맞이는 과거를 돌아보고 새로운 시작을 다짐하는 중요한 시기입니다. 가족과 친구들이 모여 서로를 격려하고 새해의 행복과 성공을 기원하며, 이는 과거의 아쉬움을 지우고 더 나은 미래를 향한 계기가 됩니다.
#
# 슬라이드 3: 새해 음식
#
# 1. 슬라이드 제목: 새해 음식
#
# 2. 주요 내용 포인트:
# - 한국의 대표적인 새해 음식: 떡국, 나물, 돼지고기 요리 등
# - 떡국은 새해를 맞이하는 대표 음식으로, 새해 첫날 먹으면 한 살 더 먹는다고 믿음
# - 나물은 새해의 건강과 다복을 기원하는 의미가 있음
# - 돼지고기는 풍요와 행복을 상징하는 음식으로, 새해 첫날 먹는다고 함
#
# 3. 관련 데이터 또는 예시:
# - 설날 연휴 기간 동안 가족들이 함께 모여 떡국, 나물, 돼지고기 요리를 즐김
# - 새해 첫날 아침에 먹는 떡국이 가장 대표적인 새해 음식
#
# 4. 제안 시각 자료:
# - 다양한 새해 음식의 이미지 또는 음식을 준비하는 모습의 사진
# - 새해 음식을 소개하는 인포그래픽
#
# 5. 발표자 메모:
# 새해를 맞이하는 한국의 대표적인 음식들에 대해 소개하겠습니다. 떡국, 나물, 돼지고기 요리 등은 새해의 건강, 행복, 풍요를 기원하는 의미가 담겨 있습니다. 이러한 전통 음식들은 가족과 친구들이 함께 나누며 새해를 축하하는 중요한 역할을 합니다.
#
# 슬라이드 4: 새해 풍습
#
# 1. 슬라이드 제목: 새해 풍습
#
# 2. 주요 내용 포인트:
# - 세배: 윗사람에게 새해 인사를 드리는 전통 풍습
# - 윷놀이: 흰 색 윷을 던져 점을 치는 전통 놀이
# - 제기차기: 종이로 만든 제기를 차며 노는 전통 놀이
# - 망월수: 새해 첫날 아침 일찍 일어나 달을 보며 소원을 빎
#
# 3. 관련 데이터 또는 예시:
# - 연령과 성별에 따른 세배 예법이 존재함
# - 설날 연휴 기간 동안 가족들이 함께 윷놀이와 제기차기를 즐김
# - 새해 첫날 아침 일찍 일어나 달을 보며 소원을 빌는 사람들이 많음
#
# 4. 제안 시각 자료:
# - 세배, 윷놀이, 제기차기 등의 전통 풍습을 보여주는 사진 또는 영상
# - 새해 첫날 아침 달을 바라보는 사람들의 모습을 담은 이미지
#
# 5. 발표자 메모:
# 이번 슬라이드에서는 새해 풍습에 대해 살펴보겠습니다. 세배, 윷놀이, 제기차기 등의 전통 놀이와 망월수 등의 의미 있는 풍습들은 한국 고유의 새해 문화를 보여줍니다. 이러한 풍습들은 가족과 친구들이 함께 즐기며 새해를 맞이하는 중요한 의미를 지니고 있습니다.
#
# 슬라이드 5: 새해 운세 점치기
#
# 1. 슬라이드 제목: 새해 운세 점치기
#
# 2. 주요 내용 포인트:
# - 새해 첫날 점을 치며 한 해의 운세를 살펴보는 전통 풍습
# - 토정비결: 토정 이지함이라는 학자가 창안한 운세 점치기 방식
# - 사주풀이: 태어난 년, 월, 일, 시를 바탕으로 한 운세 점치기
# - 신년운세: 전문 점술가들이 새해 운세를 점쳐 알려줌
#
# 3. 관련 데이터 또는 예시:
# - 설날 연휴 기간 동안 전국 각지에서 운세 점치기 행사가 열림
# - 많은 사람들이 새해 첫날 가족들과 함께 운세를 점쳐보는 전통이 있음
#
# 4. 제안 시각 자료:
# - 토정비결과 사주풀이를 보여주는 이미지 또는 인포그래픽
# - 새해 운세를 점치는 사람들의 모습을 담은 사진
#
# 5. 발표자 메모:
# 새해 첫날 운세를 점치는 것은 오랜 한국의 전통 풍습입니다. 토정비결, 사주풀이 등의 방식으로 한 해의 운세를 살펴보며, 전문 점술가들이 새해 운세를 알려주기도 합니다. 이를 통해 새해에 대한 기대와 희망을 품을 수 있습니다.제 6 슬라이드: 새해 선물
#
# 1. 슬라이드 제목: 새해 선물
#
# 2. 주요 내용 포인트:
#    - 새해에는 가족과 친구들에게 선물을 주고받는 것이 전통적인 풍습
#    - 선물은 사랑과 존중의 표현
#    - 실용적이고 의미 있는 선물이 좋음
#    - 전통적인 선물로는 과일, 과자, 홍삼, 전통 공예품 등이 있음
#    - 올해는 에코 친화적이고 지속 가능한 선물을 선택하는 것도 좋음
#
# 3. 관련 데이터 및 예시:
#    - 2022년 새해 선물 트렌드: 친환경 제품, 개인화된 선물, 홈케어 용품
#    - 새해 선물 비용 평균: 약 30,000원
#
# 4. 시각자료 제안:
#    - 새해 선물 아이디어 이미지
#    - 다양한 새해 선물 제품 이미지
#    - 선물 포장 방법 예시
#
# 5. 발표자 노트:
#    새해를 맞이하여 가족과 친구들에게 사랑과 감사의 마음을 전할 수 있는 선물을 선택하는 것이 중요합니다. 친환경적이고 개인적인 선물이 좋은 선택이 될 수 있습니다.
#
# 제 7 슬라이드: 새해 가족 모이기
#
# 1. 슬라이드 제목: 새해 가족 모이기
#
# 2. 주요 내용 포인트:
#    - 새해에는 가족들이 모여 함께 시간을 보내는 것이 중요한 전통
#    - 가족들이 모여 새해 인사를 나누고 함께 식사를 하는 것이 대표적
#    - 가족 간 이야기를 나누며 화합과 유대감을 강화
#    - 가족 사진 촬영, 가족 게임, 전통 놀이 등 다양한 활동을 함께 할 수 있음
#    - 가족 간 새해 계획과 목표를 공유하는 것도 좋음
#
# 3. 관련 데이터 및 예시:
#    - 새해 가족 모임 참여율: 약 85%
#    - 가족들이 즐겨하는 새해 활동: 가족 사진 촬영(60%), 전통 놀이(45%), 가족 게임(40%)
#
# 4. 시각자료 제안:
#    - 가족이 함께 모인 모습의 이미지
#    - 새해 가족 모임 현장 사진
#    - 가족들이 함께 하는 전통 놀이 이미지
#
# 5. 발표자 노트:
#    새해에는 가족들이 모여 함께 시간을 보내며 화합과 유대감을 느끼는 것이 중요합니다. 가족들이 모여 새해 인사를 나누고, 가족 게임이나 전통 놀이를 함께 즐기면서 소중한 추억을 만들 수 있습니다.
#
# 제 8 슬라이드: 새해 활동
#
# 1. 슬라이드 제목: 새해 활동
#
# 2. 주요 내용 포인트:
#    - 새해에는 전통적인 활동들이 많이 이루어짐
#    - 첫 일출 보기, 소원 빌기, 차례 지내기 등이 대표적
#    - 해마다 방문객이 늘어나는 명소들이 많음
#    - 새해에는 국내외 여행을 떠나는 사람들도 많음
#    - 새해에는 스포츠 경기나 공연 관람 등 다양한 여가 활동도 가능
#
# 3. 관련 데이터 및 예시:
#    - 첫 일출 보는 명소 방문객 수: 약 100만 명
#    - 새해 여행객 증가율: 전년 대비 약 20% 증가
#    - 새해 스포츠 경기 관람객 수: 약 50만 명
#
# 4. 시각자료 제안:
#    - 첫 일출 장면 이미지
#    - 새해 명소 모습 사진
#    - 새해 여행지 풍경 이미지
#    - 새해 스포츠 경기 현장 사진
#
# 5. 발표자 노트:
#    새해에는 전통적인 활동들이 많이 이루어지며, 국내외 여행과 스포츠 경기 관람 등 다양한 여가 활동도 가능합니다. 첫 일출 보기, 소원 빌기, 차례 지내기 등의 활동은 새해를 맞이하는 의미있는 경험이 될 수 있습니다.
#
# 제 9 슬라이드: 새해 다짐
#
# 1. 슬라이드 제목: 새해 다짐
#
# 2. 주요 내용 포인트:
#    - 새해를 맞아 새로운 시작, 변화, 목표를 설정하는 것이 중요
#    - 건강, 재정, 관계, 자기계발 등 다양한 분야에서 새해 다짐을 할 수 있음
#    - 구체적이고 실천 가능한 다짐이 중요
#    - 새해 다짐을 지키기 위해 실천 계획을 세우는 것이 효과적
#    - 가족이나 친구들과 새해 다짐을 공유하면 서로 격려할 수 있음
#
# 3. 관련 데이터 및 예시:
#    - 새해 다짐 상위 카테고리: 건강(45%), 재정(35%), 자기계발(25%)
#    - 새해 다짐 성공률: 약 25%
#    - 새해 다짐 사례: 금연, 운동 습관 만들기, 저축 목표 세우기, 취미 활동 시작하기
#
# 4. 시각자료 제안:
#    - 새해 다짐 아이콘 또는 일러스트레이션
#    - 새해 다짐을 적은 메모지 이미지
#    - 새해 다짐 달성을 격려하는 메시지 포스터
#
# 5. 발표자 노트:
#    새해는 새로운 시작과 변화를 위한 기회입니다. 건강, 재정, 관계 등 다양한 분야에서 구체적이고 실천 가능한 새해 다짐을 세우고, 이를 지키기 위한 계획을 수립하는 것이 중요합니다. 가족과 친구들과 다짐을 공유하며 서로 격려하는 것도 도움이 될 수 있습니다.
#
# 제 10 슬라이드: 새해 축하!
#
# 1. 슬라이드 제목: 새해 축하!
#
# 2. 주요 내용 포인트:
#    - 새해를 맞이하여 모두에게 행복과 건강이 가득하기를 기원
#    - 새로운 한 해가 풍요롭고 발전적인 시간이 되기를 바람
#    - 새해에는 더욱 가족과 친구들과의 유대를 돈독히 하고자 함
#    - 새로운 시작과 변화의 기회를 맞이하게 되어 기쁨
#    - 모두가 함께 새로운 희망과 꿈을 펼칠 수 있기를 기대
#
# 3. 관련 데이터 및 예시:
#    - 새해 인사말 예시: "새해 복 많이 받으세요!", "새해 복 가득하세요!", "새해 복 많이 받아 행복한 한 해 되세요!"
#
# 4. 시각자료 제안:
#    - 새해 축하 메시지 이미지 또는 아이콘
#    - 새해 축제 분위기의 이미지
#    - 가족과 친구들이 함께 새해를 축하하는 모습의 사진
#
# 5. 발표자 노트:
#    새해를 맞이하여 모두에게 행복과 건강이 가득하길 바랍니다. 새로운 시작과 변화의 기회를 맞이하게 되어 기쁨이 크며, 가족과 친구들과 함께 새로운 희망과 꿈을 펼칠 수 있기를 기대합니다. 새해 복 많이 받으세요!
#
# ### Image...
# img_output/titan_4.png
# '슬라이드 1: 새해 축제\n\n1. 슬라이드 제목: 새해 축제\n\n2. 주요 내용 포인트:\n- 한국의 대표적인 새해 축제: 설날 (Lunar New Year)\n- 설날 기간 동안 가족과 친구들이 모여 전통 음식을 나누며 즐기는 명절\n- 세배 예절, 전통놀이, 돼지고기 요리 등 다양한 행사와 풍습 있음\n- 설날 연휴 동안 전국 각지에서 축제와 불꽃놀이가 열려 새해를 맞이함\n\n3. 관련 데이터 또는 예시:\n- 설날 연휴 기간 동안 한국 전역에서 진행되는 600여 개의 축제 행사\n- 설날 연휴 기간 동안 가족과 친구들이 모여 평균 3.5일 동안 휴식을 취함\n\n4. 제안 시각 자료:\n- 설날 장면을 보여주는 사진 또는 동영상\n- 한국의 전통 놀이와 음식을 소개하는 이미지\n\n5. 발표자 메모:\n설날은 한국의 대표적인 명절로, 가족과 친구들이 모여 세배 예절을 행하고 전통 음식을 나누며 새해를 축하합니다. 이번 슬라이드에서는 설날 축제의 주요 특징과 활동을 소개하겠습니다.\n\n슬라이드 2: 새해맞이의 의미\n\n1. 슬라이드 제목: 새해맞이의 의미\n\n2. 주요 내용 포인트:\n- 새해맞이는 과거를 돌아보고 새로운 시작을 다짐하는 중요한 시기\n- 가족과 친구들이 모여 새로운 시작을 축하하며 서로를 격려하고 응원함\n- 새해에는 모든 사람들이 건강과 행복, 성공을 기원하며 희망을 품음\n- 새해맞이는 과거의 아쉬움을 지우고 더 나은 미래를 향한 계기가 됨\n\n3. 관련 데이터 또는 예시:\n- 새해맞이 시 \'새해 복 많이 받으세요\' 등의 인사말을 교환하며 서로를 축복함\n- 새해 아침 해맞이 행사에 많은 사람들이 모여 새로운 한 해의 시작을 기념함\n\n4. 제안 시각 자료:\n- 가족 및 친구들이 새해를 축하하는 모습의 사진\n- 새해 소망이나 다짐을 나타내는 이미지\n\n5. 발표자 메모:\n새해맞이는 과거를 돌아보고 새로운 시작을 다짐하는 중요한 시기입니다. 가족과 친구들이 모여 서로를 격려하고 새해의 행복과 성공을 기원하며, 이는 과거의 아쉬움을 지우고 더 나은 미래를 향한 계기가 됩니다.\n\n슬라이드 3: 새해 음식\n\n1. 슬라이드 제목: 새해 음식\n\n2. 주요 내용 포인트:\n- 한국의 대표적인 새해 음식: 떡국, 나물, 돼지고기 요리 등\n- 떡국은 새해를 맞이하는 대표 음식으로, 새해 첫날 먹으면 한 살 더 먹는다고 믿음\n- 나물은 새해의 건강과 다복을 기원하는 의미가 있음\n- 돼지고기는 풍요와 행복을 상징하는 음식으로, 새해 첫날 먹는다고 함\n\n3. 관련 데이터 또는 예시:\n- 설날 연휴 기간 동안 가족들이 함께 모여 떡국, 나물, 돼지고기 요리를 즐김\n- 새해 첫날 아침에 먹는 떡국이 가장 대표적인 새해 음식\n\n4. 제안 시각 자료:\n- 다양한 새해 음식의 이미지 또는 음식을 준비하는 모습의 사진\n- 새해 음식을 소개하는 인포그래픽\n\n5. 발표자 메모:\n새해를 맞이하는 한국의 대표적인 음식들에 대해 소개하겠습니다. 떡국, 나물, 돼지고기 요리 등은 새해의 건강, 행복, 풍요를 기원하는 의미가 담겨 있습니다. 이러한 전통 음식들은 가족과 친구들이 함께 나누며 새해를 축하하는 중요한 역할을 합니다.\n\n슬라이드 4: 새해 풍습\n\n1. 슬라이드 제목: 새해 풍습\n\n2. 주요 내용 포인트:\n- 세배: 윗사람에게 새해 인사를 드리는 전통 풍습\n- 윷놀이: 흰 색 윷을 던져 점을 치는 전통 놀이\n- 제기차기: 종이로 만든 제기를 차며 노는 전통 놀이\n- 망월수: 새해 첫날 아침 일찍 일어나 달을 보며 소원을 빎\n\n3. 관련 데이터 또는 예시:\n- 연령과 성별에 따른 세배 예법이 존재함\n- 설날 연휴 기간 동안 가족들이 함께 윷놀이와 제기차기를 즐김\n- 새해 첫날 아침 일찍 일어나 달을 보며 소원을 빌는 사람들이 많음\n\n4. 제안 시각 자료:\n- 세배, 윷놀이, 제기차기 등의 전통 풍습을 보여주는 사진 또는 영상\n- 새해 첫날 아침 달을 바라보는 사람들의 모습을 담은 이미지\n\n5. 발표자 메모:\n이번 슬라이드에서는 새해 풍습에 대해 살펴보겠습니다. 세배, 윷놀이, 제기차기 등의 전통 놀이와 망월수 등의 의미 있는 풍습들은 한국 고유의 새해 문화를 보여줍니다. 이러한 풍습들은 가족과 친구들이 함께 즐기며 새해를 맞이하는 중요한 의미를 지니고 있습니다.\n\n슬라이드 5: 새해 운세 점치기\n\n1. 슬라이드 제목: 새해 운세 점치기\n\n2. 주요 내용 포인트:\n- 새해 첫날 점을 치며 한 해의 운세를 살펴보는 전통 풍습\n- 토정비결: 토정 이지함이라는 학자가 창안한 운세 점치기 방식\n- 사주풀이: 태어난 년, 월, 일, 시를 바탕으로 한 운세 점치기\n- 신년운세: 전문 점술가들이 새해 운세를 점쳐 알려줌\n\n3. 관련 데이터 또는 예시:\n- 설날 연휴 기간 동안 전국 각지에서 운세 점치기 행사가 열림\n- 많은 사람들이 새해 첫날 가족들과 함께 운세를 점쳐보는 전통이 있음\n\n4. 제안 시각 자료:\n- 토정비결과 사주풀이를 보여주는 이미지 또는 인포그래픽\n- 새해 운세를 점치는 사람들의 모습을 담은 사진\n\n5. 발표자 메모:\n새해 첫날 운세를 점치는 것은 오랜 한국의 전통 풍습입니다. 토정비결, 사주풀이 등의 방식으로 한 해의 운세를 살펴보며, 전문 점술가들이 새해 운세를 알려주기도 합니다. 이를 통해 새해에 대한 기대와 희망을 품을 수 있습니다.제 6 슬라이드: 새해 선물\n\n1. 슬라이드 제목: 새해 선물\n\n2. 주요 내용 포인트:\n   - 새해에는 가족과 친구들에게 선물을 주고받는 것이 전통적인 풍습\n   - 선물은 사랑과 존중의 표현\n   - 실용적이고 의미 있는 선물이 좋음\n   - 전통적인 선물로는 과일, 과자, 홍삼, 전통 공예품 등이 있음\n   - 올해는 에코 친화적이고 지속 가능한 선물을 선택하는 것도 좋음\n\n3. 관련 데이터 및 예시:\n   - 2022년 새해 선물 트렌드: 친환경 제품, 개인화된 선물, 홈케어 용품\n   - 새해 선물 비용 평균: 약 30,000원\n\n4. 시각자료 제안:\n   - 새해 선물 아이디어 이미지\n   - 다양한 새해 선물 제품 이미지\n   - 선물 포장 방법 예시\n\n5. 발표자 노트:\n   새해를 맞이하여 가족과 친구들에게 사랑과 감사의 마음을 전할 수 있는 선물을 선택하는 것이 중요합니다. 친환경적이고 개인적인 선물이 좋은 선택이 될 수 있습니다.\n\n제 7 슬라이드: 새해 가족 모이기\n\n1. 슬라이드 제목: 새해 가족 모이기\n\n2. 주요 내용 포인트:\n   - 새해에는 가족들이 모여 함께 시간을 보내는 것이 중요한 전통\n   - 가족들이 모여 새해 인사를 나누고 함께 식사를 하는 것이 대표적\n   - 가족 간 이야기를 나누며 화합과 유대감을 강화\n   - 가족 사진 촬영, 가족 게임, 전통 놀이 등 다양한 활동을 함께 할 수 있음\n   - 가족 간 새해 계획과 목표를 공유하는 것도 좋음\n\n3. 관련 데이터 및 예시:\n   - 새해 가족 모임 참여율: 약 85%\n   - 가족들이 즐겨하는 새해 활동: 가족 사진 촬영(60%), 전통 놀이(45%), 가족 게임(40%)\n\n4. 시각자료 제안:\n   - 가족이 함께 모인 모습의 이미지\n   - 새해 가족 모임 현장 사진\n   - 가족들이 함께 하는 전통 놀이 이미지\n\n5. 발표자 노트:\n   새해에는 가족들이 모여 함께 시간을 보내며 화합과 유대감을 느끼는 것이 중요합니다. 가족들이 모여 새해 인사를 나누고, 가족 게임이나 전통 놀이를 함께 즐기면서 소중한 추억을 만들 수 있습니다.\n\n제 8 슬라이드: 새해 활동\n\n1. 슬라이드 제목: 새해 활동\n\n2. 주요 내용 포인트:\n   - 새해에는 전통적인 활동들이 많이 이루어짐\n   - 첫 일출 보기, 소원 빌기, 차례 지내기 등이 대표적\n   - 해마다 방문객이 늘어나는 명소들이 많음\n   - 새해에는 국내외 여행을 떠나는 사람들도 많음\n   - 새해에는 스포츠 경기나 공연 관람 등 다양한 여가 활동도 가능\n\n3. 관련 데이터 및 예시:\n   - 첫 일출 보는 명 ...
