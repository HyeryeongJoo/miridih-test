# %% [markdown]
# # Setup for Amazon Bedrock
# * Container: `conda_python3` <BR>
# * We recommend `python 3.10` or later.
#     - version check: !python -V

# %% [markdown]
# ## 0. Materials
# - Bedrock user guide
#     - https://docs.aws.amazon.com/bedrock/latest/userguide/what-is-service.html
# - Step by step vidio tutorial
#     - https://www.youtube.com/watch?v=ab1mbj0acDo

# %% [markdown]
# ## 1. 설치 내용은 아래를 참조 해주세요.

# %% [markdown]
# [Setup for Amazon Bedrock](https://github.com/aws-samples/aws-ai-ml-workshop-kr/blob/master/genai/aws-gen-ai-kr/20_applications/09_genai_analytics/setup.ipynb)

# %% [markdown]
# ## 2. Install python SDK for bedrock

# %%
install_needed = True

# %%
import os
import sys
import IPython

if install_needed:
    print("installing deps and restarting kernel")
    # !{sys.executable} -m pip install -U pip
    # !{sys.executable} -m pip install -U awscli
    # !{sys.executable} -m pip install -U botocore
    # !{sys.executable} -m pip install -U boto3
    # !{sys.executable} -m pip install -U sagemaker 
    # !{sys.executable} -m pip install -U langchain
    # !{sys.executable} -m pip install -U langgraph
    # !{sys.executable} -m pip install -U termcolor
    # !{sys.executable} -m pip install -U langchain_anthropic
    
    # IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# installing deps and restarting kernel
# Requirement already satisfied: pip in /home/sagemaker-user/.conda/lib/python3.10/site-packages (24.2)
# Collecting awscli
#   Using cached awscli-1.34.14-py3-none-any.whl.metadata (11 kB)
# Collecting botocore==1.35.14 (from awscli)
#   Using cached botocore-1.35.14-py3-none-any.whl.metadata (5.7 kB)
# Collecting docutils<0.17,>=0.10 (from awscli)
#   Using cached docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from awscli)
#   Using cached s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting PyYAML<6.1,>=3.10 (from awscli)
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Using cached rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore==1.35.14->awscli)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from botocore==1.35.14->awscli) (2.9.0)
# Collecting urllib3!=2.2.0,<3,>=1.25.4 (from botocore==1.35.14->awscli)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting pyasn1>=0.1.3 (from rsa<4.8,>=3.1.2->awscli)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.35.14->awscli) (1.16.0)
# Using cached awscli-1.34.14-py3-none-any.whl (4.5 MB)
# Using cached botocore-1.35.14-py3-none-any.whl (12.5 MB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Using cached s3transfer-0.10.2-py3-none-any.whl (82 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Installing collected packages: urllib3, PyYAML, pyasn1, jmespath, docutils, colorama, rsa, botocore, s3transfer, awscli
# Successfully installed PyYAML-6.0.2 awscli-1.34.14 botocore-1.35.14 colorama-0.4.6 docutils-0.16 jmespath-1.0.1 pyasn1-0.6.0 rsa-4.7.2 s3transfer-0.10.2 urllib3-2.2.2
# Requirement already satisfied: botocore in /home/sagemaker-user/.conda/lib/python3.10/site-packages (1.35.14)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from botocore) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from botocore) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from botocore) (2.2.2)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.16.0)
# Collecting boto3
#   Using cached boto3-1.35.14-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: botocore<1.36.0,>=1.35.14 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from boto3) (1.35.14)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.14->boto3) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.14->boto3) (2.2.2)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.14->boto3) (1.16.0)
# Using cached boto3-1.35.14-py3-none-any.whl (139 kB)
# Installing collected packages: boto3
# Successfully installed boto3-1.35.14
# Collecting sagemaker
#   Using cached sagemaker-2.231.0-py3-none-any.whl.metadata (16 kB)
# Collecting attrs<24,>=23.1.0 (from sagemaker)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: boto3<2.0,>=1.34.142 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from sagemaker) (1.35.14)
# Collecting cloudpickle==2.2.1 (from sagemaker)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting docker (from sagemaker)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting google-pasta (from sagemaker)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting importlib-metadata<7.0,>=1.4.0 (from sagemaker)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting jsonschema (from sagemaker)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting numpy<2.0,>=1.9.0 (from sagemaker)
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: packaging>=20.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from sagemaker) (24.1)
# Collecting pandas (from sagemaker)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pathos (from sagemaker)
#   Downloading pathos-0.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from sagemaker) (4.2.2)
# Collecting protobuf<5.0,>=3.12 (from sagemaker)
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: psutil in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from sagemaker) (6.0.0)
# Requirement already satisfied: pyyaml~=6.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from sagemaker) (6.0.2)
# Collecting requests (from sagemaker)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting sagemaker-core<2.0.0,>=1.0.0 (from sagemaker)
#   Using cached sagemaker_core-1.0.3-py3-none-any.whl.metadata (4.9 kB)
# Collecting schema (from sagemaker)
#   Downloading schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Collecting smdebug-rulesconfig==1.0.1 (from sagemaker)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl.metadata (943 bytes)
# Collecting tblib<4,>=1.7.0 (from sagemaker)
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Collecting tqdm (from sagemaker)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from sagemaker) (2.2.2)
# Requirement already satisfied: botocore<1.36.0,>=1.35.14 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.35.14)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from boto3<2.0,>=1.34.142->sagemaker) (0.10.2)
# Requirement already satisfied: zipp>=0.5 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.20.1)
# Collecting pydantic<3.0.0,>=1.7.0 (from sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading pydantic-2.9.0-py3-none-any.whl.metadata (146 kB)
# Collecting rich<14.0.0,>=13.0.0 (from sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading rich-13.8.0-py3-none-any.whl.metadata (18 kB)
# Collecting mock<5.0,>4.0 (from sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Using cached mock-4.0.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->sagemaker)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->sagemaker)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->sagemaker)
#   Downloading rpds_py-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting charset-normalizer<4,>=2 (from requests->sagemaker)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->sagemaker)
#   Downloading idna-3.8-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi>=2017.4.17 (from requests->sagemaker)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pandas->sagemaker) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/sagemaker-user/.local/lib/python3.10/site-packages (from pandas->sagemaker) (2024.1)
# Collecting tzdata>=2022.7 (from pandas->sagemaker)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting ppft>=1.7.6.8 (from pathos->sagemaker)
#   Downloading ppft-1.7.6.8-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.8 (from pathos->sagemaker)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.4 (from pathos->sagemaker)
#   Downloading pox-0.3.4-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.16 (from pathos->sagemaker)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.2 (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading pydantic_core-2.23.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.12.2)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached sagemaker-2.231.0-py3-none-any.whl (1.6 MB)
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached sagemaker_core-1.0.3-py3-none-any.whl (377 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 107.9 MB/s eta 0:00:00
# Downloading pathos-0.3.2-py3-none-any.whl (82 kB)
# Downloading schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading idna-3.8-py3-none-any.whl (66 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached mock-4.0.3-py3-none-any.whl (28 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Downloading pox-0.3.4-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.8-py3-none-any.whl (56 kB)
# Downloading pydantic-2.9.0-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 103.3 MB/s eta 0:00:00
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rich-13.8.0-py3-none-any.whl (241 kB)
# Downloading rpds_py-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: schema, tzdata, tqdm, tblib, smdebug-rulesconfig, rpds-py, pydantic-core, protobuf, ppft, pox, numpy, mock, mdurl, importlib-metadata, idna, google-pasta, dill, cloudpickle, charset-normalizer, certifi, attrs, annotated-types, requests, referencing, pydantic, pandas, multiprocess, markdown-it-py, rich, pathos, jsonschema-specifications, docker, jsonschema, sagemaker-core, sagemaker
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.4.0
#     Uninstalling importlib_metadata-8.4.0:
#       Successfully uninstalled importlib_metadata-8.4.0
# Successfully installed annotated-types-0.7.0 attrs-23.2.0 certifi-2024.8.30 charset-normalizer-3.3.2 cloudpickle-2.2.1 dill-0.3.8 docker-7.1.0 google-pasta-0.2.0 idna-3.8 importlib-metadata-6.11.0 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 markdown-it-py-3.0.0 mdurl-0.1.2 mock-4.0.3 multiprocess-0.70.16 numpy-1.26.4 pandas-2.2.2 pathos-0.3.2 pox-0.3.4 ppft-1.7.6.8 protobuf-4.25.4 pydantic-2.9.0 pydantic-core-2.23.2 referencing-0.35.1 requests-2.32.3 rich-13.8.0 rpds-py-0.20.0 sagemaker-2.231.0 sagemaker-core-1.0.3 schema-0.7.7 smdebug-rulesconfig-1.0.1 tblib-3.0.0 tqdm-4.66.5 tzdata-2024.1
# Collecting langchain
#   Using cached langchain-0.2.16-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain) (6.0.2)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.34-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-core<0.3.0,>=0.2.38 (from langchain)
#   Using cached langchain_core-0.2.38-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Using cached langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Using cached langsmith-0.1.116-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain) (2.9.0)
# Requirement already satisfied: requests<3,>=2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (46 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.38->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.23.2)
# Requirement already satisfied: tzdata in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting sniffio (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Using cached langchain-0.2.16-py3-none-any.whl (1.0 MB)
# Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 89.0 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached langchain_core-0.2.38-py3-none-any.whl (396 kB)
# Using cached langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.116-py3-none-any.whl (290 kB)
# Downloading SQLAlchemy-2.0.34-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 137.8 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 42.1 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Downloading yarl-1.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: tenacity, sniffio, orjson, multidict, jsonpointer, h11, greenlet, frozenlist, async-timeout, aiohappyeyeballs, yarl, SQLAlchemy, jsonpatch, httpcore, anyio, aiosignal, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed SQLAlchemy-2.0.34 aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 anyio-4.4.0 async-timeout-4.0.3 frozenlist-1.4.1 greenlet-3.0.3 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.16 langchain-core-0.2.38 langchain-text-splitters-0.2.4 langsmith-0.1.116 multidict-6.0.5 orjson-3.10.7 sniffio-1.3.1 tenacity-8.5.0 yarl-1.11.0
# Collecting langgraph
#   Using cached langgraph-0.2.19-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.2.38 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langgraph) (0.2.38)
# Collecting langgraph-checkpoint<2.0.0,>=1.0.2 (from langgraph)
#   Using cached langgraph_checkpoint-1.0.9-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.2.38->langgraph) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.2.38->langgraph) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.2.38->langgraph) (0.1.116)
# Requirement already satisfied: packaging<25,>=23.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.2.38->langgraph) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.2.38->langgraph) (2.9.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.2.38->langgraph) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.4,>=0.2.38->langgraph) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.2.38->langgraph) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.4,>=0.2.38->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.4,>=0.2.38->langgraph) (2.23.2)
# Requirement already satisfied: tzdata in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.4,>=0.2.38->langgraph) (2024.1)
# Requirement already satisfied: anyio in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (4.4.0)
# Requirement already satisfied: certifi in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (1.0.5)
# Requirement already satisfied: idna in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (3.8)
# Requirement already satisfied: sniffio in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (2.2.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.4,>=0.2.38->langgraph) (1.2.2)
# Using cached langgraph-0.2.19-py3-none-any.whl (97 kB)
# Using cached langgraph_checkpoint-1.0.9-py3-none-any.whl (15 kB)
# Installing collected packages: langgraph-checkpoint, langgraph
# Successfully installed langgraph-0.2.19 langgraph-checkpoint-1.0.9
# Collecting termcolor
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: termcolor
# Successfully installed termcolor-2.4.0
# Collecting langchain_anthropic
#   Using cached langchain_anthropic-0.1.23-py3-none-any.whl.metadata (2.2 kB)
# Collecting anthropic<1,>=0.30.0 (from langchain_anthropic)
#   Using cached anthropic-0.34.2-py3-none-any.whl.metadata (18 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from langchain_anthropic)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.26 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain_anthropic) (0.2.38)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain_anthropic) (4.4.0)
# Collecting distro<2,>=1.7.0 (from anthropic<1,>=0.30.0->langchain_anthropic)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain_anthropic) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from anthropic<1,>=0.30.0->langchain_anthropic)
#   Using cached jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain_anthropic) (2.9.0)
# Requirement already satisfied: sniffio in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain_anthropic) (1.3.1)
# Collecting tokenizers>=0.13.0 (from anthropic<1,>=0.30.0->langchain_anthropic)
#   Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain_anthropic) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (0.1.116)
# Requirement already satisfied: packaging<25,>=23.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (8.5.0)
# Requirement already satisfied: idna>=2.8 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.30.0->langchain_anthropic) (3.8)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.30.0->langchain_anthropic) (1.2.2)
# Requirement already satisfied: certifi in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.30.0->langchain_anthropic) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.30.0->langchain_anthropic) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<1,>=0.30.0->langchain_anthropic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic<1,>=0.30.0->langchain_anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic<1,>=0.30.0->langchain_anthropic) (2.23.2)
# Requirement already satisfied: tzdata in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic<1,>=0.30.0->langchain_anthropic) (2024.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain_anthropic)
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain_anthropic)
#   Downloading filelock-3.16.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain_anthropic)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm>=4.42.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain_anthropic) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sagemaker-user/.conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain_anthropic) (2.2.2)
# Using cached langchain_anthropic-0.1.23-py3-none-any.whl (21 kB)
# Using cached anthropic-0.34.2-py3-none-any.whl (891 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
# Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 116.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading filelock-3.16.0-py3-none-any.whl (16 kB)
# Installing collected packages: jiter, fsspec, filelock, distro, defusedxml, huggingface-hub, tokenizers, anthropic, langchain_anthropic
# Successfully installed anthropic-0.34.2 defusedxml-0.7.1 distro-1.9.0 filelock-3.16.0 fsspec-2024.9.0 huggingface-hub-0.24.6 jiter-0.5.0 langchain_anthropic-0.1.23 tokenizers-0.20.0
